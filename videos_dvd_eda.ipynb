# %%
import json
import pandas as pd

path='/Users/gracewainaina/Downloads/'

video_df = pd.read_csv(path+'amazon_reviews_us_Digital_Video_Download_v1_00.tsv', delimiter = '\t', quoting = 3)
video_df = video_df.dropna()
video_df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     12190288  R3FU16928EP5TC  B00AYB1482       668895143
# 1          US     30549954  R1IZHHS1MH3AQ4  B00KQD28OM       246219280
# 2          US     52895410   R52R85WC6TIAH  B01489L5LQ       534732318
# 3          US     27072354   R7HOOYTVIB0DS  B008LOVIIK       239012694
# 4          US     26939022  R1XQ2N5CDOZGNX  B0094LZMT0       535858974
#
#                            product_title        product_category  star_rating  \
# 0                  Enlightened: Season 1  Digital_Video_Download            5
# 1                                Vicious  Digital_Video_Download            5
# 2                            After Words  Digital_Video_Download            4
# 3  Masterpiece: Inspector Lewis Season 5  Digital_Video_Download            5
# 4                      On The Waterfront  Digital_Video_Download            5
#
#    helpful_votes  total_votes vine verified_purchase  \
# 0              0            0    N                 Y
# 1              0            0    N                 Y
# 2             17           18    N                 Y
# 3              0            0    N                 Y
# 4              0            0    N                 Y
#
#                                      review_headline  \
# 0         I loved it and I wish there was a season 3
# 1  As always it seems that the best shows come fr...
# 2                                     Charming movie
# 3                                         Five Stars
# 4               Brilliant film from beginning to end
#
#                                          review_body review_date
# 0  I loved it and I wish there was a season 3... ...  2015-08-31
# 1  As always it seems that the best shows come fr...  2015-08-31
# 2  This movie isn't perfect, but it gets a lot of...  2015-08-31
# 3                excellant this is what tv should be  2015-08-31
# 4  Brilliant film from beginning to end. All of t...  2015-08-31

# %%
video_df['review_date'] = pd.to_datetime(video_df.review_date, format='%Y-%m-%d %H:%M:%S')
video_df['year'] = video_df['review_date'].dt.year
video_df_yr = video_df.groupby(['year']).count()
video_df_yr
# Out:
#       marketplace  customer_id  review_id  product_id  product_parent  \
# year
# 2000            1            1          1           1               1
# 2001            1            1          1           1               1
# 2002            5            5          5           5               5
# 2003            4            4          4           4               4
# 2004            6            6          6           6               6
# 2005           11           11         11          11              11
# 2006          185          185        185         185             185
# 2007         2596         2596       2596        2596            2596
# 2008         3083         3083       3083        3083            3083
# 2009         3262         3262       3262        3262            3262
# 2010         6091         6091       6091        6091            6091
# 2011        20896        20896      20896       20896           20896
# 2012       142477       142477     142477      142477          142477
# 2013       722472       722472     722472      722472          722472
# 2014      1562505      1562505    1562505     1562505         1562505
# 2015      1593446      1593446    1593446     1593446         1593446
#
#       product_title  product_category  star_rating  helpful_votes  \
# year
# 2000              1                 1            1              1
# 2001              1                 1            1              1
# 2002              5                 5            5              5
# 2003              4                 4            4              4
# 2004              6                 6            6              6
# 2005             11                11           11             11
# 2006            185               185          185            185
# 2007           2596              2596         2596           2596
# 2008           3083              3083         3083           3083
# 2009           3262              3262         3262           3262
# 2010           6091              6091         6091           6091
# 2011          20896             20896        20896          20896
# 2012         142477            142477       142477         142477
# 2013         722472            722472       722472         722472
# 2014        1562505           1562505      1562505        1562505
# 2015        1593446           1593446      1593446        1593446
#
#       total_votes     vine  verified_purchase  review_headline  review_body  \
# year
# 2000            1        1                  1                1            1
# 2001            1        1                  1                1            1
# 2002            5        5                  5                5            5
# 2003            4        4                  4                4            4
# 2004            6        6                  6                6            6
# 2005           11       11                 11               11           11
# 2006          185      185                185              185          185
# 2007         2596     2596               2596             2596         2596
# 2008         3083     3083               3083             3083         3083
# 2009         3262     3262               3262             3262         3262
# 2010         6091     6091               6091             6091         6091
# 2011        20896    20896              20896            20896        20896
# 2012       142477   142477             142477           142477       142477
# 2013       722472   722472             722472           722472       722472
# 2014      1562505  1562505            1562505          1562505      1562505
# 2015      1593446  1593446            1593446          1593446      1593446
#
#       review_date
# year
# 2000            1
# 2001            1
# 2002            5
# 2003            4
# 2004            6
# 2005           11
# 2006          185
# 2007         2596
# 2008         3083
# 2009         3262
# 2010         6091
# 2011        20896
# 2012       142477
# 2013       722472
# 2014      1562505
# 2015      1593446

# %%
video_df[video_df['year']==2015]['star_rating'].mean()
# Out:
# 4.20156754606055

# %%
videos_2015 = video_df[video_df['year']==2015]
videos_2015_5star = videos_2015[videos_2015['star_rating']==5]
videos_2015_5star.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     12190288  R3FU16928EP5TC  B00AYB1482       668895143
# 1          US     30549954  R1IZHHS1MH3AQ4  B00KQD28OM       246219280
# 3          US     27072354   R7HOOYTVIB0DS  B008LOVIIK       239012694
# 4          US     26939022  R1XQ2N5CDOZGNX  B0094LZMT0       535858974
# 5          US      4772040  R1HCST57W334KN  B0112OSOQE        38517795
#
#                            product_title        product_category  star_rating  \
# 0                  Enlightened: Season 1  Digital_Video_Download            5
# 1                                Vicious  Digital_Video_Download            5
# 3  Masterpiece: Inspector Lewis Season 5  Digital_Video_Download            5
# 4                      On The Waterfront  Digital_Video_Download            5
# 5                Rick and Morty Season 2  Digital_Video_Download            5
#
#    helpful_votes  total_votes vine verified_purchase  \
# 0              0            0    N                 Y
# 1              0            0    N                 Y
# 3              0            0    N                 Y
# 4              0            0    N                 Y
# 5              5            6    N                 Y
#
#                                      review_headline  \
# 0         I loved it and I wish there was a season 3
# 1  As always it seems that the best shows come fr...
# 3                                         Five Stars
# 4               Brilliant film from beginning to end
# 5                          Best show on TV right now
#
#                                          review_body review_date  year
# 0  I loved it and I wish there was a season 3... ...  2015-08-31  2015
# 1  As always it seems that the best shows come fr...  2015-08-31  2015
# 3                excellant this is what tv should be  2015-08-31  2015
# 4  Brilliant film from beginning to end. All of t...  2015-08-31  2015
# 5  If you don't like this show. Go back to your n...  2015-08-31  2015

# %%
dvd_df = pd.read_csv(path+'amazon_reviews_us_Video_DVD_v1_00.tsv', delimiter = '\t', quoting = 3)
dvd_df = dvd_df.dropna()
dvd_df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     27288431   R33UPQQUZQEM8  B005T4ND06       400024643
# 1          US     13722556  R3IKTNQQPD9662  B004EPZ070       685335564
# 2          US     20381037  R3U27V5QMCP27T  B005S9EKCW       922008804
# 3          US     24852644  R2TOH2QKNK4IOC  B00FC1ZCB4       326560548
# 4          US     15556113  R2XQG5NJ59UFMY  B002ZG98Z0       637495038
#
#                                        product_title product_category  \
# 0  Yoga for Movement Disorders DVD: Rebuilding St...        Video DVD
# 1                                 Something Borrowed        Video DVD
# 2                    Les Miserables (2012) [Blu-ray]        Video DVD
# 3    Alien Anthology and Prometheus Bundle [Blu-ray]        Video DVD
# 4                                 Sex and the City 2        Video DVD
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0            5              3            3    N                 Y
# 1            5              0            0    N                 Y
# 2            5              1            1    N                 Y
# 3            5              0            1    N                 Y
# 4            5              0            0    N                 Y
#
#                                      review_headline  \
# 0  This was a gift for my aunt who has Parkinson'...
# 1                                         Five Stars
# 2                                       Great movie!
# 3                                            Amazing
# 4                                         Five Stars
#
#                                          review_body review_date
# 0  This was a gift for my aunt who has Parkinson'...  2015-08-31
# 1                                Teats my heart out.  2015-08-31
# 2                                       Great movie.  2015-08-31
# 3  My husband was so excited to receive these as ...  2015-08-31
# 4                                  Love this series.  2015-08-31

# %%
dvd_df['review_date'] = pd.to_datetime(dvd_df.review_date, format='%Y-%m-%d %H:%M:%S')
dvd_df['year'] = dvd_df['review_date'].dt.year
dvd_df_yr = dvd_df.groupby(['year']).count()
dvd_df_yr
# Out:
#       marketplace  customer_id  review_id  product_id  product_parent  \
# year
# 1996            3            3          3           3               3
# 1997            8            8          8           8               8
# 1998         1252         1252       1252        1252            1252
# 1999        15408        15408      15408       15408           15408
# 2000        46292        46292      46292       46292           46292
# 2001        66119        66119      66119       66119           66119
# 2002        92997        92997      92997       92997           92997
# 2003       115343       115343     115343      115343          115343
# 2004       146246       146246     146246      146246          146246
# 2005       170615       170615     170615      170615          170615
# 2006       178490       178490     178490      178490          178490
# 2007       242095       242095     242095      242095          242095
# 2008       237422       237422     237422      237422          237422
# 2009       253676       253676     253676      253676          253676
# 2010       250218       250218     250218      250218          250218
# 2011       270315       270315     270315      270315          270315
# 2012       366836       366836     366836      366836          366836
# 2013       793380       793380     793380      793380          793380
# 2014      1006750      1006750    1006750     1006750         1006750
# 2015       815577       815577     815577      815577          815577
#
#       product_title  product_category  star_rating  helpful_votes  \
# year
# 1996              3                 3            3              3
# 1997              8                 8            8              8
# 1998           1252              1252         1252           1252
# 1999          15408             15408        15408          15408
# 2000          46292             46292        46292          46292
# 2001          66119             66119        66119          66119
# 2002          92997             92997        92997          92997
# 2003         115343            115343       115343         115343
# 2004         146246            146246       146246         146246
# 2005         170615            170615       170615         170615
# 2006         178490            178490       178490         178490
# 2007         242095            242095       242095         242095
# 2008         237422            237422       237422         237422
# 2009         253676            253676       253676         253676
# 2010         250218            250218       250218         250218
# 2011         270315            270315       270315         270315
# 2012         366836            366836       366836         366836
# 2013         793380            793380       793380         793380
# 2014        1006750           1006750      1006750        1006750
# 2015         815577            815577       815577         815577
#
#       total_votes     vine  verified_purchase  review_headline  review_body  \
# year
# 1996            3        3                  3                3            3
# 1997            8        8                  8                8            8
# 1998         1252     1252               1252             1252         1252
# 1999        15408    15408              15408            15408        15408
# 2000        46292    46292              46292            46292        46292
# 2001        66119    66119              66119            66119        66119
# 2002        92997    92997              92997            92997        92997
# 2003       115343   115343             115343           115343       115343
# 2004       146246   146246             146246           146246       146246
# 2005       170615   170615             170615           170615       170615
# 2006       178490   178490             178490           178490       178490
# 2007       242095   242095             242095           242095       242095
# 2008       237422   237422             237422           237422       237422
# 2009       253676   253676             253676           253676       253676
# 2010       250218   250218             250218           250218       250218
# 2011       270315   270315             270315           270315       270315
# 2012       366836   366836             366836           366836       366836
# 2013       793380   793380             793380           793380       793380
# 2014      1006750  1006750            1006750          1006750      1006750
# 2015       815577   815577             815577           815577       815577
#
#       review_date
# year
# 1996            3
# 1997            8
# 1998         1252
# 1999        15408
# 2000        46292
# 2001        66119
# 2002        92997
# 2003       115343
# 2004       146246
# 2005       170615
# 2006       178490
# 2007       242095
# 2008       237422
# 2009       253676
# 2010       250218
# 2011       270315
# 2012       366836
# 2013       793380
# 2014      1006750
# 2015       815577

# %%
dvd_df[dvd_df['year']==2015]['star_rating'].mean()
# Out:
# 4.537581368773274

# %%
dvd_2015 = dvd_df[dvd_df['year']==2015]
dvd_2015_5star = dvd_2015[dvd_2015['star_rating']==5]
dvd_2015_5star.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     27288431   R33UPQQUZQEM8  B005T4ND06       400024643
# 1          US     13722556  R3IKTNQQPD9662  B004EPZ070       685335564
# 2          US     20381037  R3U27V5QMCP27T  B005S9EKCW       922008804
# 3          US     24852644  R2TOH2QKNK4IOC  B00FC1ZCB4       326560548
# 4          US     15556113  R2XQG5NJ59UFMY  B002ZG98Z0       637495038
#
#                                        product_title product_category  \
# 0  Yoga for Movement Disorders DVD: Rebuilding St...        Video DVD
# 1                                 Something Borrowed        Video DVD
# 2                    Les Miserables (2012) [Blu-ray]        Video DVD
# 3    Alien Anthology and Prometheus Bundle [Blu-ray]        Video DVD
# 4                                 Sex and the City 2        Video DVD
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0            5              3            3    N                 Y
# 1            5              0            0    N                 Y
# 2            5              1            1    N                 Y
# 3            5              0            1    N                 Y
# 4            5              0            0    N                 Y
#
#                                      review_headline  \
# 0  This was a gift for my aunt who has Parkinson'...
# 1                                         Five Stars
# 2                                       Great movie!
# 3                                            Amazing
# 4                                         Five Stars
#
#                                          review_body review_date  year
# 0  This was a gift for my aunt who has Parkinson'...  2015-08-31  2015
# 1                                Teats my heart out.  2015-08-31  2015
# 2                                       Great movie.  2015-08-31  2015
# 3  My husband was so excited to receive these as ...  2015-08-31  2015
# 4                                  Love this series.  2015-08-31  2015

# %%
videos_2015['product_title'].isin(dvd_2015['product_title']).value_counts()
# Out:
# False    1048630
# True      544816
# Name: product_title, dtype: int64

# %%
len(videos_2015[videos_2015['product_title'].isin(dvd_2015['product_title'])]['product_title'].unique())
# Out:
# 11716

# %%
len(videos_2015['product_title'].unique())
# Out:
# 53479

# %%
len(dvd_2015['product_title'].unique())
# Out:
# 120935

# %%
issa_match_videos = videos_2015[videos_2015['product_title'].isin(dvd_2015['product_title']) == True]
issa_match_videos
# Out:
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 0                US     12190288  R3FU16928EP5TC  B00AYB1482       668895143
# 1                US     30549954  R1IZHHS1MH3AQ4  B00KQD28OM       246219280
# 6                US     12910040  R32BUTYQS1ZJBQ  B000NPE5SA       373323715
# 7                US     38805573    RH4SXPL4L9QU  B00XWV4QXG       633842417
# 14               US     12411752  R2SWNCCEH2HPM5  B01347T9O8       331499516
# ...             ...          ...             ...         ...             ...
# 1593511          US     47832584   RIFHWS7C59SG0  B00JKJR7NK       554811333
# 1593512          US     35914474   RFKO1ZX2SN5XI  B00NY4UIKG        89974743
# 1593515          US     13410943  R3M10P5F7RDNJB  B004Z4QW8G        62616843
# 1593516          US     28580841  R1UPYGQOD95J8D  B00FH89NBC       785276382
# 1593518          US     38533490  R1V5BI4MALKZ26  B00OPX5VHK       375289410
#
#                  product_title        product_category  star_rating  \
# 0        Enlightened: Season 1  Digital_Video_Download            5
# 1                      Vicious  Digital_Video_Download            5
# 6               Africa Screams  Digital_Video_Download            4
# 7          Entourage: Season 7  Digital_Video_Download            3
# 14                    Casanova  Digital_Video_Download            1
# ...                        ...                     ...          ...
# 1593511       A Big Love Story  Digital_Video_Download            5
# 1593512          The Equalizer  Digital_Video_Download            5
# 1593515           Best Friends  Digital_Video_Download            5
# 1593516            Rescue Dawn  Digital_Video_Download            4
# 1593518          Earth to Echo  Digital_Video_Download            4
#
#          helpful_votes  total_votes vine verified_purchase  \
# 0                    0            0    N                 Y
# 1                    0            0    N                 Y
# 6                    1            1    N                 Y
# 7                    0            0    N                 Y
# 14                   0            0    N                 Y
# ...                ...          ...  ...               ...
# 1593511              1            1    N                 N
# 1593512              0            0    N                 Y
# 1593515              0            0    N                 N
# 1593516              0            0    N                 N
# 1593518              0            0    N                 Y
#
#                                            review_headline  \
# 0               I loved it and I wish there was a season 3
# 1        As always it seems that the best shows come fr...
# 6                    Very funny. A typical mid 50's comedy
# 7                         it was not as good as the series
# 14                                                One Star
# ...                                                    ...
# 1593511                                         Five Stars
# 1593512                                          loved it!
# 1593515                                     Best show ever
# 1593516                                         Four Stars
# 1593518                                      Nice For kids
#
#                                                review_body review_date  year
# 0        I loved it and I wish there was a season 3... ...  2015-08-31  2015
# 1        As always it seems that the best shows come fr...  2015-08-31  2015
# 6                  Very funny.  A typical mid 50's comedy.  2015-08-31  2015
# 7        Strange as it is, it was not as good as the se...  2015-08-31  2015
# 14             Not my kind of movie, one star was too much  2015-08-31  2015
# ...                                                    ...         ...   ...
# 1593511                   Great movie, great Story, funny.  2015-01-01  2015
# 1593512  Awesome film...loved the OCD that Denzel Washi...  2015-01-01  2015
# 1593515  Super funny!!!! My entire family loved this sh...  2015-01-01  2015
# 1593516                                   Enjoyable movie.  2015-01-01  2015
# 1593518  Nice For kids ,shows a  friends loyalty to a s...  2015-01-01  2015
#
# [544816 rows x 16 columns]

# %%
titles = issa_match_videos['product_title'].unique()
titles
# Out:
# array(['Enlightened: Season 1', 'Vicious', 'Africa Screams', ...,
#        'Love and Other Drugs', 'Loosies', 'Best Friends'], dtype=object)

# %%
import numpy as np

videos_dvd_2015 = pd.DataFrame(titles,columns=['titles'])
videos_2015_mean = videos_2015[videos_2015['product_title'].isin(titles)==True].groupby(['product_title']).mean()
videos_dvd_2015['star_rating_videos'] = np.array(videos_2015_mean['star_rating'])

videos_dvd_2015
# Out:
#                                                   titles  star_rating_videos
# 0                                  Enlightened: Season 1            5.000000
# 1                                                Vicious            2.000000
# 2                                         Africa Screams            2.500000
# 3                                    Entourage: Season 7            1.000000
# 4                                               Casanova            3.800000
# ...                                                  ...                 ...
# 11711  Serving in Silence: The Colonel Margarethe Cam...            2.000000
# 11712                                      Rambling Rose            5.000000
# 11713                               Love and Other Drugs            3.000000
# 11714                                            Loosies            4.000000
# 11715                                       Best Friends            4.166667
#
# [11716 rows x 2 columns]

# %%
dvd_2015_mean = dvd_2015[dvd_2015['product_title'].isin(titles)==True].groupby(['product_title']).mean()
videos_dvd_2015['star_rating_dvd'] = np.array(dvd_2015_mean['star_rating'])

videos_dvd_2015
# Out:
#                                                   titles  star_rating_videos  \
# 0                                  Enlightened: Season 1            5.000000
# 1                                                Vicious            2.000000
# 2                                         Africa Screams            2.500000
# 3                                    Entourage: Season 7            1.000000
# 4                                               Casanova            3.800000
# ...                                                  ...                 ...
# 11711  Serving in Silence: The Colonel Margarethe Cam...            2.000000
# 11712                                      Rambling Rose            5.000000
# 11713                               Love and Other Drugs            3.000000
# 11714                                            Loosies            4.000000
# 11715                                       Best Friends            4.166667
#
#        star_rating_dvd
# 0                  4.0
# 1                  5.0
# 2                  5.0
# 3                  5.0
# 4                  1.0
# ...                ...
# 11711              5.0
# 11712              5.0
# 11713              4.0
# 11714              3.5
# 11715              2.0
#
# [11716 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [7, 7]

# %%
videos_dvd_2015.plot(kind='scatter', x='star_rating_videos', y='star_rating_dvd', xlabel='video star rating', ylabel='dvd star rating')
plt.title("Scatter plot showing video star ratings vs DVD star rating")
plt.show()

# %%
import statsmodels.api as sm
from statsmodels.graphics.gofplots import qqplot_2samples

fig = qqplot_2samples(sm.ProbPlot(videos_dvd_2015['star_rating_videos']), sm.ProbPlot(videos_dvd_2015['star_rating_dvd']), line='45', xlabel='Video star ratings', ylabel='DVD star ratings')
plt.title("QQ Plot showing the distribution of ratings for videos and DVDs")
plt.show()

# %%
top_videos = videos_dvd_2015[videos_dvd_2015['star_rating_videos']==5]
top_videos
# Out:
#                       titles  star_rating_videos  star_rating_dvd
# 0      Enlightened: Season 1                 5.0         4.000000
# 13                 Five Days                 5.0         4.250000
# 17               World War Z                 5.0         4.166667
# 18     The Harbinger Decoded                 5.0         5.000000
# 19               24 Season 1                 5.0         5.000000
# ...                      ...                 ...              ...
# 11682               Shrieker                 5.0         5.000000
# 11685             Radio Days                 5.0         5.000000
# 11691                Big Sur                 5.0         4.500000
# 11701       Chilly Christmas                 5.0         3.666667
# 11712          Rambling Rose                 5.0         5.000000
#
# [1735 rows x 3 columns]

# %%
top_videos.plot(kind='scatter', x='star_rating_dvd', y='star_rating_videos', xlabel='dvd star rating', ylabel='video star rating')
plt.title("Scatter plot showing videos with 5 star ratings against their DVD star rating counterparts")
plt.show()

# %%
top_dvd = videos_dvd_2015[videos_dvd_2015['star_rating_dvd']==5]
top_dvd
# Out:
#                                                   titles  star_rating_videos  \
# 1                                                Vicious            2.000000
# 2                                         Africa Screams            2.500000
# 3                                    Entourage: Season 7            1.000000
# 18                                 The Harbinger Decoded            5.000000
# 19                                           24 Season 1            5.000000
# ...                                                  ...                 ...
# 11699                                   Le Quattro Volte            1.909091
# 11700                    Charlie Brown's Christmas Tales            1.000000
# 11705                              Isshinryu Karate Kata            3.500000
# 11711  Serving in Silence: The Colonel Margarethe Cam...            2.000000
# 11712                                      Rambling Rose            5.000000
#
#        star_rating_dvd
# 1                  5.0
# 2                  5.0
# 3                  5.0
# 18                 5.0
# 19                 5.0
# ...                ...
# 11699              5.0
# 11700              5.0
# 11705              5.0
# 11711              5.0
# 11712              5.0
#
# [2973 rows x 3 columns]

# %%
top_dvd.plot(kind='scatter', x='star_rating_videos', y='star_rating_dvd', xlabel='video star rating', ylabel='dvd star rating')
plt.title("Scatter plot showing DVDs with 5 star ratings against their DVD star rating counterparts")
plt.show()

# %%
top_videos_dvd = top_videos[top_videos['titles'].isin(top_dvd['titles']) == True]
top_videos_dvd
# Out:
#                       titles  star_rating_videos  star_rating_dvd
# 18     The Harbinger Decoded                 5.0              5.0
# 19               24 Season 1                 5.0              5.0
# 58          The Green Hornet                 5.0              5.0
# 64       Escape From Zahrain                 5.0              5.0
# 65            The Blind Side                 5.0              5.0
# ...                      ...                 ...              ...
# 11627            Freedomland                 5.0              5.0
# 11643      I Bury the Living                 5.0              5.0
# 11682               Shrieker                 5.0              5.0
# 11685             Radio Days                 5.0              5.0
# 11712          Rambling Rose                 5.0              5.0
#
# [647 rows x 3 columns]

# %% [markdown]
# ### Sentiment Analysis

# %%
videos_2015['label'] = videos_2015['star_rating'].apply(lambda x:0 if x < 4 else 1)
videos_2015.head()
# Out:
# /var/folders/bl/g392mrpj77s6gwry28jqpkhm0000gn/T/ipykernel_45979/317707965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   videos_2015['label'] = videos_2015['star_rating'].apply(lambda x:0 if x < 4 else 1)
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     12190288  R3FU16928EP5TC  B00AYB1482       668895143
# 1          US     30549954  R1IZHHS1MH3AQ4  B00KQD28OM       246219280
# 2          US     52895410   R52R85WC6TIAH  B01489L5LQ       534732318
# 3          US     27072354   R7HOOYTVIB0DS  B008LOVIIK       239012694
# 4          US     26939022  R1XQ2N5CDOZGNX  B0094LZMT0       535858974
#
#                            product_title        product_category  star_rating  \
# 0                  Enlightened: Season 1  Digital_Video_Download            5
# 1                                Vicious  Digital_Video_Download            5
# 2                            After Words  Digital_Video_Download            4
# 3  Masterpiece: Inspector Lewis Season 5  Digital_Video_Download            5
# 4                      On The Waterfront  Digital_Video_Download            5
#
#    helpful_votes  total_votes vine verified_purchase  \
# 0              0            0    N                 Y
# 1              0            0    N                 Y
# 2             17           18    N                 Y
# 3              0            0    N                 Y
# 4              0            0    N                 Y
#
#                                      review_headline  \
# 0         I loved it and I wish there was a season 3
# 1  As always it seems that the best shows come fr...
# 2                                     Charming movie
# 3                                         Five Stars
# 4               Brilliant film from beginning to end
#
#                                          review_body review_date  year  label
# 0  I loved it and I wish there was a season 3... ...  2015-08-31  2015      1
# 1  As always it seems that the best shows come fr...  2015-08-31  2015      1
# 2  This movie isn't perfect, but it gets a lot of...  2015-08-31  2015      1
# 3                excellant this is what tv should be  2015-08-31  2015      1
# 4  Brilliant film from beginning to end. All of t...  2015-08-31  2015      1

# %%
import nltk
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.corpus import wordnet
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer
import string

def get_pos_tag(pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('V'):
        return wordnet.VERB
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

def clean_text(text):
    # lower text
    text = text.lower()
    # tokenize text and remove puncutation
    text = [word.strip(string.punctuation) for word in text.split(" ")]
    # remove words that contain numbers
    text = [word for word in text if not any(c.isdigit() for c in word)]
    # remove stop words
    stop = stopwords.words('english')
    text = [x for x in text if x not in stop]
    # remove empty tokens
    text = [t for t in text if len(t) > 0]
    # pos tag text
    pos_tags = pos_tag(text)
    # lemmatize text
    text = [WordNetLemmatizer().lemmatize(t[0], get_pos_tag(t[1])) for t in pos_tags]
    # remove words with only one letter
    text = [t for t in text if len(t) > 1]
    # join all
    text = " ".join(text)
    return(text)

# videos_2015['clean_review'] = videos_2015['review_headline'].apply(lambda x: clean_text(x))
# videos_2015.head()

# clean text data
videos_2015_sample = videos_2015.sample(frac=0.1, replace=False, random_state=42)
videos_2015_sample['clean_review'] = videos_2015_sample['review_body'].apply(lambda x: clean_text(x))
videos_2015_sample.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/gracewainaina/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/gracewainaina/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/gracewainaina/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 424468           US     11975563  R3IECZNPY89PEY  B004NFX4II       818758700
# 31583            US     48739196   RO4XYVM9SSCBL  B00PSLQYWE       156264553
# 1537900          US      8980363  R2JNGVR6FYM1KX  B00FN42CXG       693937580
# 287074           US     13681652   RSSY5PP268JYS  B00LPPS4WU       391709567
# 1208451          US      2383459  R2WKV2563A50R2  B00QJ4DWTM       221090175
#
#                       product_title        product_category  star_rating  \
# 424468   Deuce Bigalow: Male Gigolo  Digital_Video_Download            5
# 31583        Downton Abbey Season 5  Digital_Video_Download            5
# 1537900     Sesame Street Season 43  Digital_Video_Download            5
# 287074          Jamie Marks Is Dead  Digital_Video_Download            4
# 1208451      The Americans Season 2  Digital_Video_Download            5
#
#          helpful_votes  total_votes vine verified_purchase review_headline  \
# 424468               0            0    N                 Y      Five Stars
# 31583                0            0    N                 Y      Five Stars
# 1537900              0            0    N                 N      Five Stars
# 287074               0            1    N                 Y      Four Stars
# 1208451              0            0    N                 Y      Five Stars
#
#                                review_body review_date  year  label  \
# 424468                           Classic!!  2015-07-09  2015      1
# 31583                          I loved it!  2015-08-28  2015      1
# 1537900  Can't go wrong with the classics!  2015-01-07  2015      1
# 287074            The polt could be better  2015-07-25  2015      1
# 1208451                        amazing ...  2015-03-10  2015      1
#
#                    clean_review
# 424468                  classic
# 31583                      love
# 1537900  can't go wrong classic
# 287074        polt could better
# 1208451                   amaze

# %%
# add sentiment anaylsis columns
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')

sid = SentimentIntensityAnalyzer()
videos_2015_sample['sentiments'] = videos_2015_sample['clean_review'].apply(lambda x: sid.polarity_scores(x))
videos_2015_sample = pd.concat([videos_2015_sample.drop(['sentiments'], axis=1), videos_2015_sample['sentiments'].apply(pd.Series)], axis=1)
videos_2015_sample.head(20)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/gracewainaina/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 424468           US     11975563  R3IECZNPY89PEY  B004NFX4II       818758700
# 31583            US     48739196   RO4XYVM9SSCBL  B00PSLQYWE       156264553
# 1537900          US      8980363  R2JNGVR6FYM1KX  B00FN42CXG       693937580
# 287074           US     13681652   RSSY5PP268JYS  B00LPPS4WU       391709567
# 1208451          US      2383459  R2WKV2563A50R2  B00QJ4DWTM       221090175
# 1312620          US      1693921  R1KVH5378OWC6T  B00H7NEXYC       723174135
# 987221           US     31163047  R1IH1HGSB5RUD7  B0064MPXFA       241785351
# 752299           US     41273289  R17S1W7TW85U32  B0071O7WDG       701682268
# 181266           US     35382724  R1KA67MAWJVF8E  B005544TRQ       436223062
# 201528           US     15531817  R2EAPDYEU8K7J6  B00BN4VX26       295563283
# 1208534          US     29595391  R1A2KM60K475FQ  B00B99QH62       119248934
# 1356555          US     32693833  R1CF85I9TBZZFI  B00HWPYPA2       333890315
# 856173           US     38308585  R37P290OH8FY74  B00N4PF50I       391709567
# 212403           US     13165100  R3PND7RERMPH3A  B002P3EQ1Y       492042624
# 1389103          US     15834231  R31VZH5L25IVOD  B0026ATDQE       221710301
# 865493           US     15829294  R28S5CNM9NCZQY  B003KJF2WE        32055653
# 1031940          US        87996  R2US8M0Y60IAVW  B0040I09RM       117036067
# 618078           US     52708798  R2C7ZK5VQWTDU1  B00AE2EEN8       625911919
# 833315           US     52039801  R3S9FAS49KUA5L  B00ESNDQWY       800032943
# 906047           US      2197688  R28AWISHRNQC5X  B008Y71BA4       103856724
#
#                         product_title        product_category  star_rating  \
# 424468     Deuce Bigalow: Male Gigolo  Digital_Video_Download            5
# 31583          Downton Abbey Season 5  Digital_Video_Download            5
# 1537900       Sesame Street Season 43  Digital_Video_Download            5
# 287074            Jamie Marks Is Dead  Digital_Video_Download            4
# 1208451        The Americans Season 2  Digital_Video_Download            5
# 1312620            Justified Season 5  Digital_Video_Download            4
# 987221        The Good Wife, Season 1  Digital_Video_Download            5
# 752299              Deadwood Season 3  Digital_Video_Download            5
# 181266                 Suits Season 1  Digital_Video_Download            5
# 201528                        6 Souls  Digital_Video_Download            4
# 1208534                          Nora  Digital_Video_Download            1
# 1356555                  The O'Briens  Digital_Video_Download            5
# 856173            Jamie Marks Is Dead  Digital_Video_Download            5
# 212403      Ken Burns: American Lives  Digital_Video_Download            5
# 1389103  The Host (English Subtitled)  Digital_Video_Download            5
# 865493            The Incredible Hulk  Digital_Video_Download            5
# 1031940      Sons of Anarchy Season 1  Digital_Video_Download            5
# 618078                 Luck: Season 1  Digital_Video_Download            5
# 833315        The Good Wife, Season 5  Digital_Video_Download            5
# 906047              Good Will Hunting  Digital_Video_Download            5
#
#          helpful_votes  total_votes  ...  \
# 424468               0            0  ...
# 31583                0            0  ...
# 1537900              0            0  ...
# 287074               0            1  ...
# 1208451              0            0  ...
# 1312620              0            0  ...
# 987221               0            0  ...
# 752299               0            0  ...
# 181266               0            0  ...
# 201528               0            0  ...
# 1208534              0            2  ...
# 1356555              0            1  ...
# 856173               7            9  ...
# 212403               0            0  ...
# 1389103              0            0  ...
# 865493               0            0  ...
# 1031940              0            0  ...
# 618078               0            0  ...
# 833315               0            0  ...
# 906047               0            1  ...
#
#                                            review_headline  \
# 424468                                          Five Stars
# 31583                                           Five Stars
# 1537900                                         Five Stars
# 287074                                          Four Stars
# 1208451                                         Five Stars
# 1312620                                              great
# 987221                                a really great show!
# 752299                                          Five Stars
# 181266                                          Five Stars
# 201528                                          Good movie
# 1208534                                           One Star
# 1356555                                         Five Stars
# 856173                                   Subtle and moving
# 212403                                          Five Stars
# 1389103                                         Five Stars
# 865493                                  Good mindless fun!
# 1031940  I think the show is great, I LOVE all the char...
# 618078                                          Five Stars
# 833315                        An Excellent series --5*****
# 906047                                          Five Stars
#
#                                                review_body review_date  year  \
# 424468                                           Classic!!  2015-07-09  2015
# 31583                                          I loved it!  2015-08-28  2015
# 1537900                  Can't go wrong with the classics!  2015-01-07  2015
# 287074                            The polt could be better  2015-07-25  2015
# 1208451                                        amazing ...  2015-03-10  2015
# 1312620                         one of the best shows ever  2015-02-28  2015
# 987221   I think this is one of the best shows on telev...  2015-04-08  2015
# 752299   The best show ever! Excellent acting, incredib...  2015-05-16  2015
# 181266                                         Great show!  2015-08-10  2015
# 201528   I know this movie got a lot of bad reviews but...  2015-08-08  2015
# 1208534                                Did not like it....  2015-03-10  2015
# 1356555                                Havn't read it yet.  2015-02-22  2015
# 856173   This film is an exceptionally subtle and movin...  2015-04-29  2015
# 212403   Very well done.........what else would you exp...  2015-08-07  2015
# 1389103                                      Great movie!!  2015-02-20  2015
# 865493   An added bonus is how they (vaguely) tie it in...  2015-04-29  2015
# 1031940  I think the show is great,  I LOVE all the cha...  2015-04-02  2015
# 618078   Great actors, amazing visuals of the horses ra...  2015-06-08  2015
# 833315   Well written, directed and acted.  You will fi...  2015-05-02  2015
# 906047                        One of the best movies EVER.  2015-04-20  2015
#
#         label                                       clean_review    neg  \
# 424468      1                                            classic  0.000
# 31583       1                                               love  0.000
# 1537900     1                             can't go wrong classic  0.000
# 287074      1                                  polt could better  0.000
# 1208451     1                                              amaze  0.000
# 1312620     1                                 one best show ever  0.000
# 987221      1  think one best show television cover life love...  0.000
# 752299      1  best show ever excellent act incredible write ...  0.000
# 181266      1                                         great show  0.000
# 201528      1     know movie get lot bad review personally enjoy  0.276
# 1208534     0                                               like  0.000
# 1356555     1                                    havn't read yet  0.000
# 856173      1  film exceptionally subtle move portrayal teen-...  0.071
# 212403      1  well done.........what else would expect ken burn  0.000
# 1389103     1                                        great movie  0.000
# 865493      1            add bonus vaguely tie avenger franchise  0.000
# 1031940     1  think show great love character think clay as ...  0.145
# 618078      1               great actor amaze visuals horse race  0.000
# 833315      1  well write direct acted find something good ba...  0.257
# 906047      1                                one best movie ever  0.000
#
#            neu    pos  compound
# 424468   1.000  0.000    0.0000
# 31583    0.000  1.000    0.6369
# 1537900  0.540  0.460    0.3724
# 287074   0.408  0.592    0.4404
# 1208451  0.000  1.000    0.5423
# 1312620  0.417  0.583    0.6369
# 987221   0.350  0.650    0.9565
# 752299   0.331  0.669    0.9201
# 181266   0.196  0.804    0.6249
# 201528   0.472  0.252   -0.0772
# 1208534  0.000  1.000    0.3612
# 1356555  1.000  0.000    0.0000
# 856173   0.711  0.218    0.9661
# 212403   0.741  0.259    0.2732
# 1389103  0.196  0.804    0.6249
# 865493   0.588  0.412    0.5423
# 1031940  0.467  0.388    0.7351
# 618078   0.345  0.655    0.8225
# 833315   0.558  0.186   -0.4404
# 906047   0.417  0.583    0.6369
#
# [20 rows x 22 columns]

# %%
# add number of characters column
videos_2015_sample["nb_chars"] = videos_2015_sample['clean_review'].apply(lambda x: len(x))

# add number of words column
videos_2015_sample["nb_words"] = videos_2015_sample['clean_review'].apply(lambda x: len(x.split(" ")))

# %%
# vector represantations for every review
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(videos_2015_sample['clean_review'].apply(lambda x: x.split(" ")))]

# train a Doc2Vec model with our text data
model = Doc2Vec(documents, vector_size=5, window=2, min_count=1, workers=4)

# transform each document into a vector data
doc2vec_df = videos_2015_sample['clean_review'].apply(lambda x: model.infer_vector(x.split(" "))).apply(pd.Series)
doc2vec_df.columns = ["doc2vec_vector_" + str(x) for x in doc2vec_df.columns]
videos_2015_sample = pd.concat([videos_2015_sample, doc2vec_df], axis=1)
videos_2015_sample.head()
# Out:
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 424468           US     11975563  R3IECZNPY89PEY  B004NFX4II       818758700
# 31583            US     48739196   RO4XYVM9SSCBL  B00PSLQYWE       156264553
# 1537900          US      8980363  R2JNGVR6FYM1KX  B00FN42CXG       693937580
# 287074           US     13681652   RSSY5PP268JYS  B00LPPS4WU       391709567
# 1208451          US      2383459  R2WKV2563A50R2  B00QJ4DWTM       221090175
#
#                       product_title        product_category  star_rating  \
# 424468   Deuce Bigalow: Male Gigolo  Digital_Video_Download            5
# 31583        Downton Abbey Season 5  Digital_Video_Download            5
# 1537900     Sesame Street Season 43  Digital_Video_Download            5
# 287074          Jamie Marks Is Dead  Digital_Video_Download            4
# 1208451      The Americans Season 2  Digital_Video_Download            5
#
#          helpful_votes  total_votes  ...    neu    pos compound nb_chars  \
# 424468               0            0  ...  1.000  0.000   0.0000        7
# 31583                0            0  ...  0.000  1.000   0.6369        4
# 1537900              0            0  ...  0.540  0.460   0.3724       22
# 287074               0            1  ...  0.408  0.592   0.4404       17
# 1208451              0            0  ...  0.000  1.000   0.5423        5
#
#         nb_words  doc2vec_vector_0  doc2vec_vector_1 doc2vec_vector_2  \
# 424468         1          0.156493          0.145059         0.035289
# 31583          1          0.047649          0.023583        -0.030517
# 1537900        4         -0.050270         -0.086593         0.093740
# 287074         3          0.075216          0.136775         0.070133
# 1208451        1          0.122849          0.161925         0.017056
#
#          doc2vec_vector_3  doc2vec_vector_4
# 424468          -0.236425          0.062695
# 31583           -0.051570         -0.087830
# 1537900          0.001660          0.013006
# 287074           0.014295          0.113957
# 1208451         -0.079455         -0.012636
#
# [5 rows x 29 columns]

# %%
videos_2015_sample.columns
# Out:
# Index(['marketplace', 'customer_id', 'review_id', 'product_id',
#        'product_parent', 'product_title', 'product_category', 'star_rating',
#        'helpful_votes', 'total_votes', 'vine', 'verified_purchase',
#        'review_headline', 'review_body', 'review_date', 'year', 'label',
#        'clean_review', 'neg', 'neu', 'pos', 'compound', 'nb_chars', 'nb_words',
#        'doc2vec_vector_0', 'doc2vec_vector_1', 'doc2vec_vector_2',
#        'doc2vec_vector_3', 'doc2vec_vector_4'],
#       dtype='object')

# %%
# add tf-idfs columns
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(stop_words='english',min_df = 10,max_features = 500)
tfidf_result = tfidf.fit_transform(videos_2015_sample['clean_review']).toarray()
tfidf_df = pd.DataFrame(tfidf_result, columns = tfidf.get_feature_names())
tfidf_df.columns = ["word_" + str(x) for x in tfidf_df.columns]
tfidf_df.index = videos_2015_sample.index
videos_2015_sample = pd.concat([videos_2015_sample, tfidf_df], axis=1)
videos_2015_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159345 entries, 424468 to 489701
# Columns: 1529 entries, marketplace to word_young
# dtypes: datetime64[ns](1), float32(5), float64(1504), int64(9), object(10)
# memory usage: 1.8+ GB

# %%
# show good and bad review distribution
videos_2015_sample['label'].value_counts(normalize = True)
# Out:
# 1    0.7909
# 0    0.2091
# Name: label, dtype: float64

# %%
# wordcloud function

from wordcloud import WordCloud
import matplotlib.pyplot as plt

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color = 'white',
        max_words = 200,
        max_font_size = 40, 
        scale = 3,
        random_state = 42
    ).generate(str(data))

    fig = plt.figure(1, figsize = (20, 20))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize = 20)
        fig.subplots_adjust(top = 2.3)

    plt.imshow(wordcloud)
    plt.show()
    
# print wordcloud
show_wordcloud(videos_2015_sample['review_body'])

# %%
# highest positive sentiment reviews (with more than 5 words)
videos_2015_sample[videos_2015_sample["nb_words"] >= 5].sort_values("pos", ascending = False)[["review_body", "pos"]].head(10)
# Out:
#                                                review_body  pos
# 230341        Silly, funny. great for a laugh! I liked it!  1.0
# 29207    Awesome, awesome, awesome, awesome, awesome, a...  1.0
# 1132051  Funny, good entertainment, great adventure, gr...  1.0
# 996880         Such good comedy. Solid and silly. Love it.  1.0
# 751242                           love love love love love.  1.0
# 2315      Pretty pretty pretty pretty pretty pretty GREAT!  1.0
# 564018   If you like silly comedy you'll love this. As ...  1.0
# 1588518   Pretty entertaining. Not an award winner but fun  1.0
# 89154          It's pretty good pretty pretty pretty good!  1.0
# 961392                Pretty, pretty, pretty, pretty good.  1.0

# %%
# lowest negative sentiment reviews (with more than 5 words)
videos_2015_sample[videos_2015_sample["nb_words"] >= 5].sort_values("neg", ascending = False)[["review_body", "neg"]].head(10)
# Out:
#                                                review_body    neg
# 510087   Awful, meaningless violent garbage. The worst....  0.951
# 408392                  AWFUL AWFUL AWFUL. Did I say AWFUL  0.923
# 1341241  Not scary at all. Night of the living dead is ...  0.843
# 596957   So sad a tragedy.  Maybe it was the topic.  It...  0.843
# 739808   Why the violence? Why the disgusting sound eff...  0.843
# 656409                    BAD acting, BAD script, just BAD  0.840
# 286542   TERRIBLE AND PATHETIC. JLO IS WORST ACTRESS......  0.837
# 825967   I Hate this movie and it sucked and i hate eve...  0.837
# 1472383  My 2 year old is obsessed!  &#34;Stinky dirty!...  0.837
# 173259           HORRIBLE!!!!! Bad acting, worthless plot.  0.832

# %%
# plot sentiment distribution for positive and negative reviews

import seaborn as sns

for x in [0, 1]:
    subset = videos_2015_sample[videos_2015_sample['label'] == x]
    
    # Draw the density plot
    if x == 0:
        label = "bad reviews"
    else:
        label = "good reviews"
    sns.distplot(subset['compound'], hist = False, label = label)
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Modelling labels for video reviews

# %%
# feature selection
ignore_cols = ['label', 'review_headline', 'review_body', 'clean_review']
features = [c for c in videos_2015_sample.columns if c not in ignore_cols]

# %%
len(features)
# Out:
# 1525

# %%
# split the data into train and test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(videos_2015_sample[features], videos_2015_sample['label'], test_size=0.30, random_state=42, shuffle=False)

# %%
# train a random forest classifier
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 100, random_state = 42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# show feature importance
feature_importances_df = pd.DataFrame({"feature": features, "importance": rf.feature_importances_}).sort_values("importance", ascending = False)
feature_importances_df.head(20)

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
for col in X_train.columns:
    X_train[col] = le.fit_transform(X_train[col])

for col in X_test.columns:
    X_test[col] = le.fit_transform(X_test[col])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/bl/g392mrpj77s6gwry28jqpkhm0000gn/T/ipykernel_45979/4265659498.py in <module>
#       3 le = preprocessing.LabelEncoder()
#       4 for col in X_train.columns:
# ----> 5     X_train[col] = le.fit_transform(X_train[col])
#       6
#       7 for col in X_test.columns:
#
# /usr/local/lib/python3.9/site-packages/sklearn/preprocessing/_label.py in fit_transform(self, y)
#     113             Encoded labels.
#     114         """
# --> 115         y = column_or_1d(y, warn=True)
#     116         self.classes_, y = _unique(y, return_inverse=True)
#     117         return y
#
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py in column_or_1d(y, warn)
#    1022         return np.ravel(y)
#    1023
# -> 1024     raise ValueError(
#    1025         "y should be a 1d array, got an array of shape {} instead.".format(shape)
#    1026     )
#
# ValueError: y should be a 1d array, got an array of shape (111541, 9) instead.

# %%
pip install tensorflow --upgrade
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/bl/g392mrpj77s6gwry28jqpkhm0000gn/T/ipykernel_41624/3759192867.py in <module>
# ----> 1 get_ipython().run_line_magic('conda', 'install tensorflow')
#
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2349                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2350             with self.builtin_trap:
# -> 2351                 result = fn(*args, **kwargs)
#    2352             return result
#    2353
#
# /usr/local/lib/python3.9/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# /usr/local/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.9/site-packages/IPython/core/magics/packaging.py in conda(self, line)
#      84         """
#      85         if not _is_conda_environment():
# ---> 86             raise ValueError("The python kernel does not appear to be a conda environment.  "
#      87                              "Please use ``%pip install`` instead.")
#      88
#
# ValueError: The python kernel does not appear to be a conda environment.  Please use ``%pip install`` instead.

# %%
import tensorflow as tf

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# train a random forest classifier
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 100, random_state = 42)
rf.fit(X_train, y_train)

# show feature importance
feature_importances_df = pd.DataFrame({"feature": features, "importance": rf.feature_importances_}).sort_values("importance", ascending = False)
feature_importances_df.head(20)

# %%
# ROC curve
from sklearn.metrics import roc_curve, auc, roc_auc_score
import matplotlib.pyplot as plt

y_pred = [x[1] for x in rf.predict_proba(X_test)]
fpr, tpr, thresholds = roc_curve(y_test, y_pred, pos_label = 1)

roc_auc = auc(fpr, tpr)

plt.figure(1, figsize = (15, 10))
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
# PR curve
from sklearn.metrics import average_precision_score, precision_recall_curve
from sklearn.utils.fixes import signature

average_precision = average_precision_score(y_test, y_pred)

precision, recall, _ = precision_recall_curve(y_test, y_pred)

# In matplotlib < 1.5, plt.fill_between does not have a 'step' argument
step_kwargs = ({'step': 'post'}
               if 'step' in signature(plt.fill_between).parameters
               else {})

plt.figure(1, figsize = (15, 10))
plt.step(recall, precision, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, alpha=0.2, color='b', **step_kwargs)

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(average_precision))

# %%
dvd_2015
