# %%
import json
import pandas as pd

path='/Users/gracewainaina/Downloads/'

video_df = pd.read_csv(path+'amazon_reviews_us_Digital_Video_Download_v1_00.tsv', delimiter = '\t', quoting = 3)
video_df = video_df.dropna()
video_df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     12190288  R3FU16928EP5TC  B00AYB1482       668895143
# 1          US     30549954  R1IZHHS1MH3AQ4  B00KQD28OM       246219280
# 2          US     52895410   R52R85WC6TIAH  B01489L5LQ       534732318
# 3          US     27072354   R7HOOYTVIB0DS  B008LOVIIK       239012694
# 4          US     26939022  R1XQ2N5CDOZGNX  B0094LZMT0       535858974
#
#                            product_title        product_category  star_rating  \
# 0                  Enlightened: Season 1  Digital_Video_Download            5
# 1                                Vicious  Digital_Video_Download            5
# 2                            After Words  Digital_Video_Download            4
# 3  Masterpiece: Inspector Lewis Season 5  Digital_Video_Download            5
# 4                      On The Waterfront  Digital_Video_Download            5
#
#    helpful_votes  total_votes vine verified_purchase  \
# ...

# %%
video_df['review_date'] = pd.to_datetime(video_df.review_date, format='%Y-%m-%d %H:%M:%S')
video_df['year'] = video_df['review_date'].dt.year
video_df_yr = video_df.groupby(['year']).count()
video_df_yr
# Out:
#       marketplace  customer_id  review_id  product_id  product_parent  \
# year
# 2000            1            1          1           1               1
# 2001            1            1          1           1               1
# 2002            5            5          5           5               5
# 2003            4            4          4           4               4
# 2004            6            6          6           6               6
# 2005           11           11         11          11              11
# 2006          185          185        185         185             185
# 2007         2596         2596       2596        2596            2596
# 2008         3083         3083       3083        3083            3083
# 2009         3262         3262       3262        3262            3262
# 2010         6091         6091       6091        6091            6091
# 2011        20896        20896      20896       20896           20896
# ...

# %%
video_df[video_df['year']==2015]['star_rating'].mean()
# Out:
# 4.20156754606055

# %%
videos_2015 = video_df[video_df['year']==2015]
videos_2015_5star = videos_2015[videos_2015['star_rating']==5]
videos_2015_5star.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     12190288  R3FU16928EP5TC  B00AYB1482       668895143
# 1          US     30549954  R1IZHHS1MH3AQ4  B00KQD28OM       246219280
# 3          US     27072354   R7HOOYTVIB0DS  B008LOVIIK       239012694
# 4          US     26939022  R1XQ2N5CDOZGNX  B0094LZMT0       535858974
# 5          US      4772040  R1HCST57W334KN  B0112OSOQE        38517795
#
#                            product_title        product_category  star_rating  \
# 0                  Enlightened: Season 1  Digital_Video_Download            5
# 1                                Vicious  Digital_Video_Download            5
# 3  Masterpiece: Inspector Lewis Season 5  Digital_Video_Download            5
# 4                      On The Waterfront  Digital_Video_Download            5
# 5                Rick and Morty Season 2  Digital_Video_Download            5
#
#    helpful_votes  total_votes vine verified_purchase  \
# ...

# %%
dvd_df = pd.read_csv(path+'amazon_reviews_us_Video_DVD_v1_00.tsv', delimiter = '\t', quoting = 3)
dvd_df = dvd_df.dropna()
dvd_df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     27288431   R33UPQQUZQEM8  B005T4ND06       400024643
# 1          US     13722556  R3IKTNQQPD9662  B004EPZ070       685335564
# 2          US     20381037  R3U27V5QMCP27T  B005S9EKCW       922008804
# 3          US     24852644  R2TOH2QKNK4IOC  B00FC1ZCB4       326560548
# 4          US     15556113  R2XQG5NJ59UFMY  B002ZG98Z0       637495038
#
#                                        product_title product_category  \
# 0  Yoga for Movement Disorders DVD: Rebuilding St...        Video DVD
# 1                                 Something Borrowed        Video DVD
# 2                    Les Miserables (2012) [Blu-ray]        Video DVD
# 3    Alien Anthology and Prometheus Bundle [Blu-ray]        Video DVD
# 4                                 Sex and the City 2        Video DVD
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# ...

# %%
dvd_df['review_date'] = pd.to_datetime(dvd_df.review_date, format='%Y-%m-%d %H:%M:%S')
dvd_df['year'] = dvd_df['review_date'].dt.year
dvd_df_yr = dvd_df.groupby(['year']).count()
dvd_df_yr
# Out:
#       marketplace  customer_id  review_id  product_id  product_parent  \
# year
# 1996            3            3          3           3               3
# 1997            8            8          8           8               8
# 1998         1252         1252       1252        1252            1252
# 1999        15408        15408      15408       15408           15408
# 2000        46292        46292      46292       46292           46292
# 2001        66119        66119      66119       66119           66119
# 2002        92997        92997      92997       92997           92997
# 2003       115343       115343     115343      115343          115343
# 2004       146246       146246     146246      146246          146246
# 2005       170615       170615     170615      170615          170615
# 2006       178490       178490     178490      178490          178490
# 2007       242095       242095     242095      242095          242095
# ...

# %%
dvd_df[dvd_df['year']==2015]['star_rating'].mean()
# Out:
# 4.537581368773274

# %%
dvd_2015 = dvd_df[dvd_df['year']==2015]
dvd_2015_5star = dvd_2015[dvd_2015['star_rating']==5]
dvd_2015_5star.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     27288431   R33UPQQUZQEM8  B005T4ND06       400024643
# 1          US     13722556  R3IKTNQQPD9662  B004EPZ070       685335564
# 2          US     20381037  R3U27V5QMCP27T  B005S9EKCW       922008804
# 3          US     24852644  R2TOH2QKNK4IOC  B00FC1ZCB4       326560548
# 4          US     15556113  R2XQG5NJ59UFMY  B002ZG98Z0       637495038
#
#                                        product_title product_category  \
# 0  Yoga for Movement Disorders DVD: Rebuilding St...        Video DVD
# 1                                 Something Borrowed        Video DVD
# 2                    Les Miserables (2012) [Blu-ray]        Video DVD
# 3    Alien Anthology and Prometheus Bundle [Blu-ray]        Video DVD
# 4                                 Sex and the City 2        Video DVD
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# ...

# %%
videos_2015['product_title'].isin(dvd_2015['product_title']).value_counts()
# Out:
# False    1048630
# True      544816
# Name: product_title, dtype: int64

# %%
len(videos_2015[videos_2015['product_title'].isin(dvd_2015['product_title'])]['product_title'].unique())
# Out:
# 11716

# %%
len(videos_2015['product_title'].unique())
# Out:
# 53479

# %%
len(dvd_2015['product_title'].unique())
# Out:
# 120935

# %%
# movies/ series found in both digital videos and DVDs
issa_match_videos = videos_2015[videos_2015['product_title'].isin(dvd_2015['product_title']) == True]
issa_match_videos.head()
# Out:
#    marketplace  customer_id       review_id  product_id  product_parent  \
# 0           US     12190288  R3FU16928EP5TC  B00AYB1482       668895143
# 1           US     30549954  R1IZHHS1MH3AQ4  B00KQD28OM       246219280
# 6           US     12910040  R32BUTYQS1ZJBQ  B000NPE5SA       373323715
# 7           US     38805573    RH4SXPL4L9QU  B00XWV4QXG       633842417
# 14          US     12411752  R2SWNCCEH2HPM5  B01347T9O8       331499516
#
#             product_title        product_category  star_rating  helpful_votes  \
# 0   Enlightened: Season 1  Digital_Video_Download            5              0
# 1                 Vicious  Digital_Video_Download            5              0
# 6          Africa Screams  Digital_Video_Download            4              1
# 7     Entourage: Season 7  Digital_Video_Download            3              0
# 14               Casanova  Digital_Video_Download            1              0
#
#     total_votes vine verified_purchase  \
# ...

# %%
titles = issa_match_videos['product_title'].unique()
titles
# Out:
# array(['Enlightened: Season 1', 'Vicious', 'Africa Screams', ...,
#        'Love and Other Drugs', 'Loosies', 'Best Friends'], dtype=object)

# %%
import numpy as np

videos_dvd_2015_ratings = pd.DataFrame(titles,columns=['titles'])
videos_2015_mean = videos_2015[videos_2015['product_title'].isin(titles)==True].groupby(['product_title']).mean()
videos_dvd_2015_ratings['star_rating_videos'] = np.array(videos_2015_mean['star_rating'])

videos_dvd_2015_ratings
# Out:
#                                                   titles  star_rating_videos
# 0                                  Enlightened: Season 1            5.000000
# 1                                                Vicious            2.000000
# 2                                         Africa Screams            2.500000
# 3                                    Entourage: Season 7            1.000000
# 4                                               Casanova            3.800000
# ...                                                  ...                 ...
# 11711  Serving in Silence: The Colonel Margarethe Cam...            2.000000
# 11712                                      Rambling Rose            5.000000
# 11713                               Love and Other Drugs            3.000000
# 11714                                            Loosies            4.000000
# 11715                                       Best Friends            4.166667
#
# [11716 rows x 2 columns]

# %% [markdown]
# ### Merging star ratings for digital videos and DVDs

# %%
dvd_2015_mean = dvd_2015[dvd_2015['product_title'].isin(titles)==True].groupby(['product_title']).mean()
videos_dvd_2015_ratings['star_rating_dvd'] = np.array(dvd_2015_mean['star_rating'])

videos_dvd_2015_ratings
# Out:
#                                                   titles  star_rating_videos  \
# 0                                  Enlightened: Season 1            5.000000
# 1                                                Vicious            2.000000
# 2                                         Africa Screams            2.500000
# 3                                    Entourage: Season 7            1.000000
# 4                                               Casanova            3.800000
# ...                                                  ...                 ...
# 11711  Serving in Silence: The Colonel Margarethe Cam...            2.000000
# 11712                                      Rambling Rose            5.000000
# 11713                               Love and Other Drugs            3.000000
# 11714                                            Loosies            4.000000
# 11715                                       Best Friends            4.166667
#
#        star_rating_dvd
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Ratings EDA

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [7, 7]

# %%
videos_dvd_2015_ratings.plot(kind='scatter', x='star_rating_videos', y='star_rating_dvd', xlabel='video star rating', ylabel='dvd star rating')
plt.title("Scatter plot showing video star ratings vs DVD star rating")
plt.show()

# %%
import scipy.stats
scipy.stats.pearsonr(videos_dvd_2015_ratings['star_rating_videos'], videos_dvd_2015_ratings['star_rating_dvd'])
# Out:
# (0.2697395801697661, 1.9149907760301282e-194)

# %%
scipy.stats.spearmanr(videos_dvd_2015_ratings['star_rating_videos'], videos_dvd_2015_ratings['star_rating_dvd'])
# Out:
# SpearmanrResult(correlation=0.22850062141255795, pvalue=1.2709240189472858e-138)

# %%
import statsmodels.api as sm
from statsmodels.graphics.gofplots import qqplot_2samples

fig = qqplot_2samples(sm.ProbPlot(videos_dvd_2015_ratings['star_rating_videos']), sm.ProbPlot(videos_dvd_2015_ratings['star_rating_dvd']), line='45', xlabel='Video star ratings', ylabel='DVD star ratings')
plt.title("QQ Plot showing the distribution of ratings for videos and DVDs")
plt.show()

# %%
top_videos = videos_dvd_2015_ratings[videos_dvd_2015_ratings['star_rating_videos']==5]
top_videos
# Out:
#                       titles  star_rating_videos  star_rating_dvd
# 0      Enlightened: Season 1                 5.0         4.000000
# 13                 Five Days                 5.0         4.250000
# 17               World War Z                 5.0         4.166667
# 18     The Harbinger Decoded                 5.0         5.000000
# 19               24 Season 1                 5.0         5.000000
# ...                      ...                 ...              ...
# 11682               Shrieker                 5.0         5.000000
# 11685             Radio Days                 5.0         5.000000
# 11691                Big Sur                 5.0         4.500000
# 11701       Chilly Christmas                 5.0         3.666667
# 11712          Rambling Rose                 5.0         5.000000
#
# [1735 rows x 3 columns]

# %%
top_videos.plot(kind='scatter', x='star_rating_dvd', y='star_rating_videos', xlabel='dvd star rating', ylabel='video star rating')
plt.title("Scatter plot showing videos with 5 star ratings against their DVD star rating counterparts")
plt.show()

# %%
top_dvd = videos_dvd_2015_ratings[videos_dvd_2015_ratings['star_rating_dvd']==5]
top_dvd
# Out:
#                                                   titles  star_rating_videos  \
# 1                                                Vicious            2.000000
# 2                                         Africa Screams            2.500000
# 3                                    Entourage: Season 7            1.000000
# 18                                 The Harbinger Decoded            5.000000
# 19                                           24 Season 1            5.000000
# ...                                                  ...                 ...
# 11699                                   Le Quattro Volte            1.909091
# 11700                    Charlie Brown's Christmas Tales            1.000000
# 11705                              Isshinryu Karate Kata            3.500000
# 11711  Serving in Silence: The Colonel Margarethe Cam...            2.000000
# 11712                                      Rambling Rose            5.000000
#
#        star_rating_dvd
# ...

# %%
top_dvd.plot(kind='scatter', x='star_rating_videos', y='star_rating_dvd', xlabel='video star rating', ylabel='dvd star rating')
plt.title("Scatter plot showing DVDs with 5 star ratings against their DVD star rating counterparts")
plt.show()

# %%
top_videos_dvd = top_videos[top_videos['titles'].isin(top_dvd['titles']) == True]
top_videos_dvd
# Out:
#                       titles  star_rating_videos  star_rating_dvd
# 18     The Harbinger Decoded                 5.0              5.0
# 19               24 Season 1                 5.0              5.0
# 58          The Green Hornet                 5.0              5.0
# 64       Escape From Zahrain                 5.0              5.0
# 65            The Blind Side                 5.0              5.0
# ...                      ...                 ...              ...
# 11627            Freedomland                 5.0              5.0
# 11643      I Bury the Living                 5.0              5.0
# 11682               Shrieker                 5.0              5.0
# 11685             Radio Days                 5.0              5.0
# 11712          Rambling Rose                 5.0              5.0
#
# [647 rows x 3 columns]

# %% [markdown]
# ### Reviews EDA

# %%
# wordcloud function

from wordcloud import WordCloud
import matplotlib.pyplot as plt

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color = 'white',
        max_words = 200,
        max_font_size = 40, 
        scale = 3,
        random_state = 42
    ).generate(str(data))

    fig = plt.figure(1, figsize = (20, 20))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize = 20)
        fig.subplots_adjust(top = 2.3)

    plt.imshow(wordcloud)
    plt.show()

# %%
# digital videos wordcloud
show_wordcloud(videos_2015['review_body'])

# %%
# DVD wordcloud
show_wordcloud(dvd_2015['review_body'])

# %% [markdown]
# ### Sentiment Analysis

# %%
videos_2015['label'] = videos_2015['star_rating'].apply(lambda x:0 if x < 4 else 1)
videos_2015.head()
# Out:
# /var/folders/bl/g392mrpj77s6gwry28jqpkhm0000gn/T/ipykernel_53606/317707965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   videos_2015['label'] = videos_2015['star_rating'].apply(lambda x:0 if x < 4 else 1)
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     12190288  R3FU16928EP5TC  B00AYB1482       668895143
# 1          US     30549954  R1IZHHS1MH3AQ4  B00KQD28OM       246219280
# 2          US     52895410   R52R85WC6TIAH  B01489L5LQ       534732318
# 3          US     27072354   R7HOOYTVIB0DS  B008LOVIIK       239012694
# 4          US     26939022  R1XQ2N5CDOZGNX  B0094LZMT0       535858974
#
#                            product_title        product_category  star_rating  \
# ...

# %%
videos_2015['label'].value_counts(normalize = True)
# Out:
# 1    0.791301
# 0    0.208699
# Name: label, dtype: float64

# %%
dvd_2015['label'] = dvd_2015['star_rating'].apply(lambda x:0 if x < 4 else 1)
dvd_2015.head()
# Out:
# /var/folders/bl/g392mrpj77s6gwry28jqpkhm0000gn/T/ipykernel_53606/208033049.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dvd_2015['label'] = dvd_2015['star_rating'].apply(lambda x:0 if x < 4 else 1)
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     27288431   R33UPQQUZQEM8  B005T4ND06       400024643
# 1          US     13722556  R3IKTNQQPD9662  B004EPZ070       685335564
# 2          US     20381037  R3U27V5QMCP27T  B005S9EKCW       922008804
# 3          US     24852644  R2TOH2QKNK4IOC  B00FC1ZCB4       326560548
# 4          US     15556113  R2XQG5NJ59UFMY  B002ZG98Z0       637495038
#
#                                        product_title product_category  \
# ...

# %%
dvd_2015['label'].value_counts(normalize = True)
# Out:
# 1    0.882444
# 0    0.117556
# Name: label, dtype: float64

# %%
import nltk
from nltk.corpus import wordnet
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer
import string

def get_pos_tag(pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('V'):
        return wordnet.VERB
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

def clean_text(text):
    # lower text
    text = text.lower()
    # tokenize text and remove puncutation
    text = [word.strip(string.punctuation) for word in text.split(" ")]
    # remove words that contain numbers
    text = [word for word in text if not any(c.isdigit() for c in word)]
    # remove stop words
    stop = stopwords.words('english')
    text = [x for x in text if x not in stop]
    # remove empty tokens
    text = [t for t in text if len(t) > 0]
    # pos tag text
    pos_tags = pos_tag(text)
    # lemmatize text
    text = [WordNetLemmatizer().lemmatize(t[0], get_pos_tag(t[1])) for t in pos_tags]
    # remove words with only one letter
    text = [t for t in text if len(t) > 1]
    # join all
    text = " ".join(text)
    return(text)

# %%
# sample and clean digital video reviews
videos_2015_sample = videos_2015.sample(frac=0.1, replace=False, random_state=42)
videos_2015_sample['clean_review'] = videos_2015_sample['review_body'].apply(lambda x: clean_text(x))
videos_2015_sample.head()
# Out:
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 424468           US     11975563  R3IECZNPY89PEY  B004NFX4II       818758700
# 31583            US     48739196   RO4XYVM9SSCBL  B00PSLQYWE       156264553
# 1537900          US      8980363  R2JNGVR6FYM1KX  B00FN42CXG       693937580
# 287074           US     13681652   RSSY5PP268JYS  B00LPPS4WU       391709567
# 1208451          US      2383459  R2WKV2563A50R2  B00QJ4DWTM       221090175
#
#                       product_title        product_category  star_rating  \
# 424468   Deuce Bigalow: Male Gigolo  Digital_Video_Download            5
# 31583        Downton Abbey Season 5  Digital_Video_Download            5
# 1537900     Sesame Street Season 43  Digital_Video_Download            5
# 287074          Jamie Marks Is Dead  Digital_Video_Download            4
# 1208451      The Americans Season 2  Digital_Video_Download            5
#
# ...

# %%
# sample and clean DVD reviews
dvd_2015_sample = dvd_2015.sample(frac=0.1, replace=False, random_state=42)
dvd_2015_sample['clean_review'] = dvd_2015_sample['review_body'].apply(lambda x: clean_text(x))
dvd_2015_sample.head()
# Out:
#        marketplace  customer_id       review_id  product_id  product_parent  \
# 102251          US     48996729  R13DQZQBVYF7MQ  B0006J021C       778365412
# 553162          US      9608307  R1Y3UCUN6YHLDI  B005OK0YPW        52929832
# 269126          US      4333470   R90YKFHGD37AX  B00BD6KXKW       529453644
# 570697          US      9992587  R3491P6YHCP8BT  B00GT83J1E       359085620
# 434939          US     12434328  R21XU7DH0P1LTG  B00TFOKJ8A       239226958
#
#                                             product_title product_category  \
# 102251  Happiest Baby: Learn to calm crying fast...hel...        Video DVD
# 553162  The Three Investigators and the Secret Of Skel...        Video DVD
# 269126                           Covert Affairs: Season 3        Video DVD
# 570697       Airplane / Airplane II: The Sequel [Blu-ray]        Video DVD
# 434939       The Hobbit: Motion Picture Trilogy (Blu-ray)        Video DVD
#
# ...

# %%
# adding sentiment anaylsis columns
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
videos_2015_sample['sentiments'] = videos_2015_sample['clean_review'].apply(lambda x: sid.polarity_scores(x))
videos_2015_sample = pd.concat([videos_2015_sample.drop(['sentiments'], axis=1), videos_2015_sample['sentiments'].apply(pd.Series)], axis=1)
videos_2015_sample.head()
# Out:
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 424468           US     11975563  R3IECZNPY89PEY  B004NFX4II       818758700
# 31583            US     48739196   RO4XYVM9SSCBL  B00PSLQYWE       156264553
# 1537900          US      8980363  R2JNGVR6FYM1KX  B00FN42CXG       693937580
# 287074           US     13681652   RSSY5PP268JYS  B00LPPS4WU       391709567
# 1208451          US      2383459  R2WKV2563A50R2  B00QJ4DWTM       221090175
#
#                       product_title        product_category  star_rating  \
# 424468   Deuce Bigalow: Male Gigolo  Digital_Video_Download            5
# 31583        Downton Abbey Season 5  Digital_Video_Download            5
# 1537900     Sesame Street Season 43  Digital_Video_Download            5
# 287074          Jamie Marks Is Dead  Digital_Video_Download            4
# 1208451      The Americans Season 2  Digital_Video_Download            5
#
#          helpful_votes  total_votes  ... review_headline  \
# ...

# %%
# adding sentiment anaylsis columns
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# nltk.download('vader_lexicon')

sid = SentimentIntensityAnalyzer()
dvd_2015_sample['sentiments'] = dvd_2015_sample['clean_review'].apply(lambda x: sid.polarity_scores(x))
dvd_2015_sample = pd.concat([dvd_2015_sample.drop(['sentiments'], axis=1), dvd_2015_sample['sentiments'].apply(pd.Series)], axis=1)
dvd_2015_sample.head()
# Out:
#        marketplace  customer_id       review_id  product_id  product_parent  \
# 102251          US     48996729  R13DQZQBVYF7MQ  B0006J021C       778365412
# 553162          US      9608307  R1Y3UCUN6YHLDI  B005OK0YPW        52929832
# 269126          US      4333470   R90YKFHGD37AX  B00BD6KXKW       529453644
# 570697          US      9992587  R3491P6YHCP8BT  B00GT83J1E       359085620
# 434939          US     12434328  R21XU7DH0P1LTG  B00TFOKJ8A       239226958
#
#                                             product_title product_category  \
# 102251  Happiest Baby: Learn to calm crying fast...hel...        Video DVD
# 553162  The Three Investigators and the Secret Of Skel...        Video DVD
# 269126                           Covert Affairs: Season 3        Video DVD
# 570697       Airplane / Airplane II: The Sequel [Blu-ray]        Video DVD
# 434939       The Hobbit: Motion Picture Trilogy (Blu-ray)        Video DVD
#
#         star_rating  helpful_votes  total_votes  ...  \
# ...

# %%
# digital videos
# add number of characters column
videos_2015_sample["nb_chars"] = videos_2015_sample['clean_review'].apply(lambda x: len(x))

# add number of words column
videos_2015_sample["nb_words"] = videos_2015_sample['clean_review'].apply(lambda x: len(x.split(" ")))

# %%
# DVD
# add number of characters column
dvd_2015_sample["nb_chars"] = dvd_2015_sample['clean_review'].apply(lambda x: len(x))

# add number of words column
dvd_2015_sample["nb_words"] = dvd_2015_sample['clean_review'].apply(lambda x: len(x.split(" ")))

# %%
# Digital video 
# add tf-idfs columns
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(stop_words='english',min_df = 10,max_features = 150)
tfidf_result = tfidf.fit_transform(videos_2015_sample['clean_review']).toarray()
tfidf.get_feature_names()
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['absolutely',
#  'act',
#  'action',
#  'actor',
#  'actually',
#  'amaze',
#  'amazon',
#  'awesome',
#  'bad',
#  'beautiful',
#  'begin',
#  'believe',
#  'best',
#  'big',
#  'bit',
#  'book',
#  'bosch',
#  'br',
#  'bring',
#  'cast',
#  'character',
#  'child',
#  'classic',
#  'come',
#  'comedy',
#  'cute',
#  'daughter',
#  'day',
#  'definitely',
#  'different',
#  'documentary',
#  'drama',
#  'end',
#  'enjoy',
#  'enjoyable',
#  'entertain',
#  'episode',
#  'especially',
#  'excellent',
#  'expect',
#  'family',
#  'fan',
#  'fantastic',
#  'far',
#  'favorite',
#  'feel',
#  'film',
#  'follow',
#  'forward',
#  'fun',
#  'funny',
#  'girl',
#  'good',
#  'great',
#  'guy',
# ...

# %%
tfidf_df = pd.DataFrame(tfidf_result, columns = tfidf.get_feature_names())
tfidf_df.columns = ["word_" + str(x) for x in tfidf_df.columns]
tfidf_df.index = videos_2015_sample.index
videos_2015_sample = pd.concat([videos_2015_sample, tfidf_df], axis=1)
videos_2015_sample.head()
# Out:
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 424468           US     11975563  R3IECZNPY89PEY  B004NFX4II       818758700
# 31583            US     48739196   RO4XYVM9SSCBL  B00PSLQYWE       156264553
# 1537900          US      8980363  R2JNGVR6FYM1KX  B00FN42CXG       693937580
# 287074           US     13681652   RSSY5PP268JYS  B00LPPS4WU       391709567
# 1208451          US      2383459  R2WKV2563A50R2  B00QJ4DWTM       221090175
#
#                       product_title        product_category  star_rating  \
# 424468   Deuce Bigalow: Male Gigolo  Digital_Video_Download            5
# 31583        Downton Abbey Season 5  Digital_Video_Download            5
# 1537900     Sesame Street Season 43  Digital_Video_Download            5
# 287074          Jamie Marks Is Dead  Digital_Video_Download            4
# 1208451      The Americans Season 2  Digital_Video_Download            5
#
# ...

# %%
# DVD 
# add tf-idfs columns
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(stop_words='english',min_df = 10,max_features = 150)
tfidf_result = tfidf.fit_transform(dvd_2015_sample['clean_review']).toarray()
tfidf.get_feature_names()
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['act',
#  'action',
#  'actor',
#  'actually',
#  'add',
#  'awesome',
#  'bad',
#  'beautiful',
#  'begin',
#  'best',
#  'big',
#  'bit',
#  'blu',
#  'book',
#  'br',
#  'bring',
#  'buy',
#  'case',
#  'cast',
#  'character',
#  'child',
#  'christmas',
#  'classic',
#  'collection',
#  'come',
#  'comedy',
#  'copy',
#  'daughter',
#  'day',
#  'different',
#  'disc',
#  'dvd',
#  'end',
#  'enjoy',
#  'episode',
#  'especially',
#  'excellent',
#  'expect',
#  'family',
#  'fan',
#  'far',
#  'fast',
#  'favorite',
#  'feature',
#  'feel',
#  'film',
#  'follow',
#  'friend',
#  'fun',
#  'funny',
#  'gift',
#  'good',
#  'great',
#  'guy',
#  'happen',
#  'happy',
#  'hard',
#  'help',
# ...

# %%
tfidf_df = pd.DataFrame(tfidf_result, columns = tfidf.get_feature_names())
tfidf_df.columns = ["word_" + str(x) for x in tfidf_df.columns]
tfidf_df.index = dvd_2015_sample.index
dvd_2015_sample = pd.concat([dvd_2015_sample, tfidf_df], axis=1)
dvd_2015_sample.head()
# Out:
#        marketplace  customer_id       review_id  product_id  product_parent  \
# 102251          US     48996729  R13DQZQBVYF7MQ  B0006J021C       778365412
# 553162          US      9608307  R1Y3UCUN6YHLDI  B005OK0YPW        52929832
# 269126          US      4333470   R90YKFHGD37AX  B00BD6KXKW       529453644
# 570697          US      9992587  R3491P6YHCP8BT  B00GT83J1E       359085620
# 434939          US     12434328  R21XU7DH0P1LTG  B00TFOKJ8A       239226958
#
#                                             product_title product_category  \
# 102251  Happiest Baby: Learn to calm crying fast...hel...        Video DVD
# 553162  The Three Investigators and the Secret Of Skel...        Video DVD
# 269126                           Covert Affairs: Season 3        Video DVD
# 570697       Airplane / Airplane II: The Sequel [Blu-ray]        Video DVD
# 434939       The Hobbit: Motion Picture Trilogy (Blu-ray)        Video DVD
#
# ...

# %%
# digital videos
# highest positive sentiment reviews (with more than 5 words)
videos_2015_sample[videos_2015_sample["nb_words"] >= 5].sort_values("pos", ascending = False)[["review_body", "pos"]].head(10)
# Out:
#                                                review_body  pos
# 230341        Silly, funny. great for a laugh! I liked it!  1.0
# 29207    Awesome, awesome, awesome, awesome, awesome, a...  1.0
# 1132051  Funny, good entertainment, great adventure, gr...  1.0
# 996880         Such good comedy. Solid and silly. Love it.  1.0
# 751242                           love love love love love.  1.0
# 2315      Pretty pretty pretty pretty pretty pretty GREAT!  1.0
# 564018   If you like silly comedy you'll love this. As ...  1.0
# 1588518   Pretty entertaining. Not an award winner but fun  1.0
# 89154          It's pretty good pretty pretty pretty good!  1.0
# 961392                Pretty, pretty, pretty, pretty good.  1.0

# %%
# digital videos
# lowest negative sentiment reviews (with more than 5 words)
videos_2015_sample[videos_2015_sample["nb_words"] >= 5].sort_values("neg", ascending = False)[["review_body", "neg"]].head(10)
# Out:
#                                                review_body    neg
# 510087   Awful, meaningless violent garbage. The worst....  0.951
# 408392                  AWFUL AWFUL AWFUL. Did I say AWFUL  0.923
# 1341241  Not scary at all. Night of the living dead is ...  0.843
# 596957   So sad a tragedy.  Maybe it was the topic.  It...  0.843
# 739808   Why the violence? Why the disgusting sound eff...  0.843
# 656409                    BAD acting, BAD script, just BAD  0.840
# 286542   TERRIBLE AND PATHETIC. JLO IS WORST ACTRESS......  0.837
# 825967   I Hate this movie and it sucked and i hate eve...  0.837
# 1472383  My 2 year old is obsessed!  &#34;Stinky dirty!...  0.837
# 173259           HORRIBLE!!!!! Bad acting, worthless plot.  0.832

# %%
# DVDs
# highest positive sentiment reviews (with more than 5 words)
dvd_2015_sample[dvd_2015_sample["nb_words"] >= 5].sort_values("pos", ascending = False)[["review_body", "pos"]].head(10)
# Out:
#                                               review_body    pos
# 168708             ok ok ok ok ok ok ok ok ok ok ok ok ok  1.000
# 733396  good good good good good good good good good g...  1.000
# 732193  good good good good good good good good good g...  1.000
# 518339                      LOVE LOVE LOVE LOVE LOVE LOVE  1.000
# 125890  GREAT!!! GREAT!!! GREAT!!! GREAT!!! GREAT!!! G...  1.000
# 353891  Love this so well worth it you will have a lau...  1.000
# 729975        YES YES YES LOVED IT GREAT FOR FANS LIKE ME  1.000
# 689595                     LOVE LOVE LOVE LOVE LOVE!!!!!!  1.000
# 518466  Love these &#34;guys&#34;!!! Smart, attractive...  0.950
# 127227  Excellent , excellent and excellent , Thank Yo...  0.947

# %%
# DVDs
# lowest negative sentiment reviews (with more than 5 words)
dvd_2015_sample[dvd_2015_sample["nb_words"] >= 5].sort_values("neg", ascending = False)[["review_body", "neg"]].head(10)
# Out:
#                                               review_body    neg
# 125677  Terrible, terrible, terrible. Don't waste your...  0.924
# 116937  Terrible movie.  Fake &#34;monsters&#34;, awfu...  0.821
# 425471  What a weird movie graphic horror all in all n...  0.817
# 446241  This ranked right up there with  boring & stup...  0.810
# 255877  It's Star Wars.  Is there anything bad about S...  0.790
# 123123               wont play in the united states sadly  0.782
# 385514  The quality is HORRIBLE. It's fuzzy and jumpy....  0.750
# 64902         poor acting and weak story. waste of money.  0.746
# 327929  Stupid movie. Bad Acting. Bad story line. Bad ...  0.734
# 613454  Really poor everything. Lousy script and lousy...  0.732

# %%
# Digital videos
# plot sentiment distribution for positive and negative reviews
import seaborn as sns
for x in [0, 1]:
    subset = videos_2015_sample[videos_2015_sample['label'] == x]
    
    # Draw the density plot
    if x == 0:
        label = "bad reviews"
    else:
        label = "good reviews"
    sns.distplot(subset['compound'], hist = False, label = label)
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# DVDs
# plot sentiment distribution for positive and negative reviews
import seaborn as sns
for x in [0, 1]:
    subset = dvd_2015_sample[dvd_2015_sample['label'] == x]
    
    # Draw the density plot
    if x == 0:
        label = "bad reviews"
    else:
        label = "good reviews"
    sns.distplot(subset['compound'], hist = False, label = label)
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
from textblob import TextBlob
# Digital Videos
videos_2015_sample['sentiments'] = videos_2015_sample[['review_body']].applymap(lambda x: TextBlob(x).sentiment.polarity)

# %%
videos_2015_sample.groupby('star_rating').mean().plot(xlabel='sentiments', y = 'sentiments', style='+-')
plt.show()

# %%
# DVDs
dvd_2015_sample['sentiments'] = dvd_2015_sample[['review_body']].applymap(lambda x: TextBlob(x).sentiment.polarity)

# %%
dvd_2015_sample.groupby('star_rating').mean().plot(xlabel='sentiments', y = 'sentiments', style='+-')
plt.show()

# %% [markdown]
# ### Modelling labels for video reviews

# %%
# feature selection
ignore_cols = ['label', 'review_headline', 'review_body', 'clean_review', 'star_rating']
features = [c for c in videos_2015_sample.columns if c not in ignore_cols]

# %%
# split the data into train and test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    videos_2015_sample.loc[:, videos_2015_sample.columns.isin(features)], 
    videos_2015_sample['label'], 
    test_size=0.30, random_state=42, shuffle=False)

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
for col in X_train.columns:
    X_train[col] = le.fit_transform(X_train[col])
for col in X_test.columns:
    X_test[col] = le.fit_transform(X_test[col])

# %%
# train a random forest classifier
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 1000, random_state = 42)
rf.fit(X_train, y_train)
pd.DataFrame({"feature": features, "importance": rf.feature_importances_}).sort_values("importance", ascending = False).head(20)
# Out:
#             feature  importance
# 169      sentiments    0.127393
# 16         compound    0.078111
# 15              pos    0.055768
# 8       total_votes    0.046728
# 13              neg    0.046410
# 3        product_id    0.042717
# 5     product_title    0.035966
# 4    product_parent    0.035891
# 1       customer_id    0.035833
# 2         review_id    0.035234
# 11      review_date    0.033781
# 17         nb_chars    0.033268
# 14              neu    0.028295
# 107         word_ok    0.022915
# 18         nb_words    0.018768
# 102      word_movie    0.013096
# 97        word_love    0.011405
# 7     helpful_votes    0.010942
# 71        word_good    0.010708
# 72       word_great    0.009522

# %%
rf.predict_proba(X_test)
# Out:
# array([[0.23 , 0.77 ],
#        [0.278, 0.722],
#        [0.135, 0.865],
#        ...,
#        [0.668, 0.332],
#        [0.235, 0.765],
#        [0.295, 0.705]])

# %%
rf.predict(X_test)
# Out:
# array([1, 1, 1, ..., 0, 1, 1])

# %%
rf.score(X_test, y_test)
# Out:
# 0.8490921261819094

# %% [markdown]
# ### Modelling labels for DVDs reviews

# %%
# feature selection
ignore_cols = ['label', 'review_headline', 'review_body', 'clean_review', 'star_rating']
features = [c for c in dvd_2015_sample.columns if c not in ignore_cols]

# %%
# split the data into train and test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    dvd_2015_sample.loc[:, dvd_2015_sample.columns.isin(features)], 
    dvd_2015_sample['label'], 
    test_size=0.30, random_state=42, shuffle=False)

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
for col in X_train.columns:
    X_train[col] = le.fit_transform(X_train[col])
for col in X_test.columns:
    X_test[col] = le.fit_transform(X_test[col])

# %%
# train a random forest classifier
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 1000, random_state = 42)
rf.fit(X_train, y_train)
pd.DataFrame({"feature": features, "importance": rf.feature_importances_}).sort_values("importance", ascending = False).head(20)
# Out:
#             feature  importance
# 169      sentiments    0.095665
# 16         compound    0.058308
# 8       total_votes    0.050369
# 15              pos    0.046456
# 13              neg    0.039623
# 1       customer_id    0.037550
# 3        product_id    0.037467
# 2         review_id    0.036569
# 5     product_title    0.036183
# 4    product_parent    0.035919
# 11      review_date    0.034699
# 17         nb_chars    0.032861
# 14              neu    0.029816
# 18         nb_words    0.022687
# 102         word_ok    0.017961
# 7     helpful_votes    0.012266
# 97       word_movie    0.011526
# 111       word_play    0.011318
# 50         word_dvd    0.010897
# 70        word_good    0.009760

# %%
rf.predict_proba(X_test)
# Out:
# array([[0.194, 0.806],
#        [0.189, 0.811],
#        [0.363, 0.637],
#        ...,
#        [0.203, 0.797],
#        [0.089, 0.911],
#        [0.452, 0.548]])

# %%
rf.score(X_test, y_test)
# Out:
# 0.9041605362105607
