# %%
import os
import json
import gzip
import pandas as pd

# %%
# !pwd
# Out:
# /Users/auraulloa/Desktop/DataSciencePipeline/project/CS396_Data_Science

# %% [markdown]
# # CD and Vinyls

# %% [markdown]
# ## Cleaning dataset

# %% [markdown]
# Summary:
# - Removed tech1, tech2, imgurl, fit, imgurlhighres, similar_item, date, and details due to not enough data
# - Removed main_cat due to unhelpful distribution and mostly misleading info
# - Cleaning the price values since there are CSS in some records
# - Clean the main category section since they have HTML containing the real category string
# - Convert lists to strings for making cleaner dataframes
# - Use main category to find unrelated items and remove them
# - Remove duplicates

# %%
path = '/Users/auraulloa/Desktop/DataSciencePipeline/'
physical_path = path + 'meta_CDs_and_Vinyl.json.gz'

# %%
### load the meta data

phys_data = []
with gzip.open(physical_path) as f:
    for l in f:
        phys_data.append(json.loads(l.strip()))
    
# total length of list, this number equals total number of products
print(len(phys_data))
# Out:
# 516914

# %% [markdown]
# There are 516,914 physical products.

# %%
# convert list into pandas dataframe

phys_df = pd.DataFrame.from_dict(phys_data)

print(len(phys_df))
# Out:
# 516914

# %%
phystemp = phys_df.fillna('')
physicals = phystemp[~phystemp.title.str.contains('getTime')] # filter those unformatted rows
print(len(physicals))
# Out:
# 516914

# %%
physicals.head()
# Out:
#                                        category tech1  \
# 0                      [CDs & Vinyl, Christian]
# 1  [CDs & Vinyl, Christian, Pop & Contemporary]
# 2          [CDs & Vinyl, Christian, Children's]
# 3          [CDs & Vinyl, Christian, Children's]
# 4          [CDs & Vinyl, Christian, Children's]
#
#                                          description fit  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [1) To God Be The Glory2) This Is My Fathers W...
# 4  [Joy To The World 2 The First Noel 3 Hark! The...
#
#                                   title  \
# 0                Songs for the Shepherd
# 1       Lift Him Up With Ron Kenoly VHS
# 2                            I Love You
# 3  Hymns: 16 Classic Hymns for Children
# 4                      Christmas Carols
#
#                                             also_buy tech2            brand  \
# 0  [B0016CP2GS, B0000075PB, B0000275QQ, B00000I7J...            Keith Green
# 1               [6303908845, 6303646611, B000008GO1]
# 2                                                 []        Integrity Music
# 3  [B00000DPLJ, B000008UPG, B00BQH9RKA, B00KYVHGR...                Sue Gay
# 4                           [B0010WAC50, B00000DPLJ]         Cedarmont Kids
#
#   feature                        rank  \
# 0      []    123,896 in CDs & Vinyl (
# 1      []    284,935 in Movies & TV (
# 2      []  1,138,833 in CDs & Vinyl (
# 3      []    271,064 in CDs & Vinyl (
# 4      []    409,293 in CDs & Vinyl (
#
#                                            also_view  \
# 0  [B0016CP2GS, B00000I7JO, B00000I9AH, B00P826ZR...
# 1                                       [B00000DUDE]
# 2                                                 []
# 3  [B00000DPLL, 0843113006, B00BQH9RKA, B000008UP...
# 4  [B00000DPKG, B0010WAC50, B00000DPKH, B00FSZPM8...
#
#                                             main_cat similar_item date  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1                                        Movies & TV
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#                                                price        asin imageURL  \
# 0                                                     0001393774       []
# 1                                                     0001501348       []
# 2                                                     0001515209       []
# 3  .a-section.a-spacing-mini{margin-bottom:6px!im...  0005072298       []
# 4                                                     0005121515       []
#
#   imageURLHighRes details
# 0              []
# 1              []
# 2              []
# 3              []
# 4              []

# %%
physicals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 516914 entries, 0 to 516913
# Data columns (total 19 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   category         516914 non-null  object
#  1   tech1            516914 non-null  object
#  2   description      516914 non-null  object
#  3   fit              516914 non-null  object
#  4   title            516914 non-null  object
#  5   also_buy         516914 non-null  object
#  6   tech2            516914 non-null  object
#  7   brand            516914 non-null  object
#  8   feature          516914 non-null  object
#  9   rank             516914 non-null  object
#  10  also_view        516914 non-null  object
#  11  main_cat         516914 non-null  object
#  12  similar_item     516914 non-null  object
#  13  date             516914 non-null  object
#  14  price            516914 non-null  object
#  15  asin             516914 non-null  object
#  16  imageURL         516914 non-null  object
#  17  imageURLHighRes  516914 non-null  object
#  18  details          516914 non-null  object
# dtypes: object(19)
# memory usage: 78.9+ MB

# %% [markdown]
# The records in the head show that a lot of columns are empty or not useful for the questions we're asking. So we should remove them in hope of speeding things up with less dimensions.

# %%
physicals[physicals["tech1"] != ""].count()
# Out:
# category           19
# tech1              19
# description        19
# fit                19
# title              19
# also_buy           19
# tech2              19
# brand              19
# feature            19
# rank               19
# also_view          19
# main_cat           19
# similar_item       19
# date               19
# price              19
# asin               19
# imageURL           19
# imageURLHighRes    19
# details            19
# dtype: int64

# %%
physicals = physicals.drop("tech1", 1)
physicals.head()
# Out:
#                                        category  \
# 0                      [CDs & Vinyl, Christian]
# 1  [CDs & Vinyl, Christian, Pop & Contemporary]
# 2          [CDs & Vinyl, Christian, Children's]
# 3          [CDs & Vinyl, Christian, Children's]
# 4          [CDs & Vinyl, Christian, Children's]
#
#                                          description fit  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [1) To God Be The Glory2) This Is My Fathers W...
# 4  [Joy To The World 2 The First Noel 3 Hark! The...
#
#                                   title  \
# 0                Songs for the Shepherd
# 1       Lift Him Up With Ron Kenoly VHS
# 2                            I Love You
# 3  Hymns: 16 Classic Hymns for Children
# 4                      Christmas Carols
#
#                                             also_buy tech2            brand  \
# 0  [B0016CP2GS, B0000075PB, B0000275QQ, B00000I7J...            Keith Green
# 1               [6303908845, 6303646611, B000008GO1]
# 2                                                 []        Integrity Music
# 3  [B00000DPLJ, B000008UPG, B00BQH9RKA, B00KYVHGR...                Sue Gay
# 4                           [B0010WAC50, B00000DPLJ]         Cedarmont Kids
#
#   feature                        rank  \
# 0      []    123,896 in CDs & Vinyl (
# 1      []    284,935 in Movies & TV (
# 2      []  1,138,833 in CDs & Vinyl (
# 3      []    271,064 in CDs & Vinyl (
# 4      []    409,293 in CDs & Vinyl (
#
#                                            also_view  \
# 0  [B0016CP2GS, B00000I7JO, B00000I9AH, B00P826ZR...
# 1                                       [B00000DUDE]
# 2                                                 []
# 3  [B00000DPLL, 0843113006, B00BQH9RKA, B000008UP...
# 4  [B00000DPKG, B0010WAC50, B00000DPKH, B00FSZPM8...
#
#                                             main_cat similar_item date  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1                                        Movies & TV
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#                                                price        asin imageURL  \
# 0                                                     0001393774       []
# 1                                                     0001501348       []
# 2                                                     0001515209       []
# 3  .a-section.a-spacing-mini{margin-bottom:6px!im...  0005072298       []
# 4                                                     0005121515       []
#
#   imageURLHighRes details
# 0              []
# 1              []
# 2              []
# 3              []
# 4              []

# %%
physicals = physicals.drop("imageURL", 1)
physicals = physicals.drop("imageURLHighRes", 1)
physicals.head()
# Out:
#                                        category  \
# 0                      [CDs & Vinyl, Christian]
# 1  [CDs & Vinyl, Christian, Pop & Contemporary]
# 2          [CDs & Vinyl, Christian, Children's]
# 3          [CDs & Vinyl, Christian, Children's]
# 4          [CDs & Vinyl, Christian, Children's]
#
#                                          description fit  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [1) To God Be The Glory2) This Is My Fathers W...
# 4  [Joy To The World 2 The First Noel 3 Hark! The...
#
#                                   title  \
# 0                Songs for the Shepherd
# 1       Lift Him Up With Ron Kenoly VHS
# 2                            I Love You
# 3  Hymns: 16 Classic Hymns for Children
# 4                      Christmas Carols
#
#                                             also_buy tech2            brand  \
# 0  [B0016CP2GS, B0000075PB, B0000275QQ, B00000I7J...            Keith Green
# 1               [6303908845, 6303646611, B000008GO1]
# 2                                                 []        Integrity Music
# 3  [B00000DPLJ, B000008UPG, B00BQH9RKA, B00KYVHGR...                Sue Gay
# 4                           [B0010WAC50, B00000DPLJ]         Cedarmont Kids
#
#   feature                        rank  \
# 0      []    123,896 in CDs & Vinyl (
# 1      []    284,935 in Movies & TV (
# 2      []  1,138,833 in CDs & Vinyl (
# 3      []    271,064 in CDs & Vinyl (
# 4      []    409,293 in CDs & Vinyl (
#
#                                            also_view  \
# 0  [B0016CP2GS, B00000I7JO, B00000I9AH, B00P826ZR...
# 1                                       [B00000DUDE]
# 2                                                 []
# 3  [B00000DPLL, 0843113006, B00BQH9RKA, B000008UP...
# 4  [B00000DPKG, B0010WAC50, B00000DPKH, B00FSZPM8...
#
#                                             main_cat similar_item date  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1                                        Movies & TV
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#                                                price        asin details
# 0                                                     0001393774
# 1                                                     0001501348
# 2                                                     0001515209
# 3  .a-section.a-spacing-mini{margin-bottom:6px!im...  0005072298
# 4                                                     0005121515

# %%
physicals[physicals["tech2"] != ""].count()
# Out:
# category        2
# description     2
# fit             2
# title           2
# also_buy        2
# tech2           2
# brand           2
# feature         2
# rank            2
# also_view       2
# main_cat        2
# similar_item    2
# date            2
# price           2
# asin            2
# details         2
# dtype: int64

# %%
physicals = physicals.drop("tech2", 1)
physicals.head()
# Out:
#                                        category  \
# 0                      [CDs & Vinyl, Christian]
# 1  [CDs & Vinyl, Christian, Pop & Contemporary]
# 2          [CDs & Vinyl, Christian, Children's]
# 3          [CDs & Vinyl, Christian, Children's]
# 4          [CDs & Vinyl, Christian, Children's]
#
#                                          description fit  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [1) To God Be The Glory2) This Is My Fathers W...
# 4  [Joy To The World 2 The First Noel 3 Hark! The...
#
#                                   title  \
# 0                Songs for the Shepherd
# 1       Lift Him Up With Ron Kenoly VHS
# 2                            I Love You
# 3  Hymns: 16 Classic Hymns for Children
# 4                      Christmas Carols
#
#                                             also_buy            brand feature  \
# 0  [B0016CP2GS, B0000075PB, B0000275QQ, B00000I7J...      Keith Green      []
# 1               [6303908845, 6303646611, B000008GO1]                       []
# 2                                                 []  Integrity Music      []
# 3  [B00000DPLJ, B000008UPG, B00BQH9RKA, B00KYVHGR...          Sue Gay      []
# 4                           [B0010WAC50, B00000DPLJ]   Cedarmont Kids      []
#
#                          rank  \
# 0    123,896 in CDs & Vinyl (
# 1    284,935 in Movies & TV (
# 2  1,138,833 in CDs & Vinyl (
# 3    271,064 in CDs & Vinyl (
# 4    409,293 in CDs & Vinyl (
#
#                                            also_view  \
# 0  [B0016CP2GS, B00000I7JO, B00000I9AH, B00P826ZR...
# 1                                       [B00000DUDE]
# 2                                                 []
# 3  [B00000DPLL, 0843113006, B00BQH9RKA, B000008UP...
# 4  [B00000DPKG, B0010WAC50, B00000DPKH, B00FSZPM8...
#
#                                             main_cat similar_item date  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1                                        Movies & TV
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#                                                price        asin details
# 0                                                     0001393774
# 1                                                     0001501348
# 2                                                     0001515209
# 3  .a-section.a-spacing-mini{margin-bottom:6px!im...  0005072298
# 4                                                     0005121515

# %%
physicals[physicals["similar_item"] != ""].count()
# Out:
# category        1
# description     1
# fit             1
# title           1
# also_buy        1
# brand           1
# feature         1
# rank            1
# also_view       1
# main_cat        1
# similar_item    1
# date            1
# price           1
# asin            1
# details         1
# dtype: int64

# %%
physicals = physicals.drop("similar_item", 1)

# %%
physicals[physicals["date"] != ""].count()
# Out:
# category       139
# description    139
# fit            139
# title          139
# also_buy       139
# brand          139
# feature        139
# rank           139
# also_view      139
# main_cat       139
# date           139
# price          139
# asin           139
# details        139
# dtype: int64

# %%
physicals = physicals.drop("date", 1)
physicals.head()
# Out:
#                                        category  \
# 0                      [CDs & Vinyl, Christian]
# 1  [CDs & Vinyl, Christian, Pop & Contemporary]
# 2          [CDs & Vinyl, Christian, Children's]
# 3          [CDs & Vinyl, Christian, Children's]
# 4          [CDs & Vinyl, Christian, Children's]
#
#                                          description fit  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [1) To God Be The Glory2) This Is My Fathers W...
# 4  [Joy To The World 2 The First Noel 3 Hark! The...
#
#                                   title  \
# 0                Songs for the Shepherd
# 1       Lift Him Up With Ron Kenoly VHS
# 2                            I Love You
# 3  Hymns: 16 Classic Hymns for Children
# 4                      Christmas Carols
#
#                                             also_buy            brand feature  \
# 0  [B0016CP2GS, B0000075PB, B0000275QQ, B00000I7J...      Keith Green      []
# 1               [6303908845, 6303646611, B000008GO1]                       []
# 2                                                 []  Integrity Music      []
# 3  [B00000DPLJ, B000008UPG, B00BQH9RKA, B00KYVHGR...          Sue Gay      []
# 4                           [B0010WAC50, B00000DPLJ]   Cedarmont Kids      []
#
#                          rank  \
# 0    123,896 in CDs & Vinyl (
# 1    284,935 in Movies & TV (
# 2  1,138,833 in CDs & Vinyl (
# 3    271,064 in CDs & Vinyl (
# 4    409,293 in CDs & Vinyl (
#
#                                            also_view  \
# 0  [B0016CP2GS, B00000I7JO, B00000I9AH, B00P826ZR...
# 1                                       [B00000DUDE]
# 2                                                 []
# 3  [B00000DPLL, 0843113006, B00BQH9RKA, B000008UP...
# 4  [B00000DPKG, B0010WAC50, B00000DPKH, B00FSZPM8...
#
#                                             main_cat  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1                                        Movies & TV
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#                                                price        asin details
# 0                                                     0001393774
# 1                                                     0001501348
# 2                                                     0001515209
# 3  .a-section.a-spacing-mini{margin-bottom:6px!im...  0005072298
# 4                                                     0005121515

# %%
physicals[physicals["details"] != ""].count()
# Out:
# category       516371
# description    516371
# fit            516371
# title          516371
# also_buy       516371
# brand          516371
# feature        516371
# rank           516371
# also_view      516371
# main_cat       516371
# price          516371
# asin           516371
# details        516371
# dtype: int64

# %% [markdown]
# Most of the records have a details section so we'll keep it.

# %%
physicals[physicals["price"] != ""].count()
# Out:
# category       378813
# description    378813
# fit            378813
# title          378813
# also_buy       378813
# brand          378813
# feature        378813
# rank           378813
# also_view      378813
# main_cat       378813
# price          378813
# asin           378813
# details        378813
# dtype: int64

# %% [markdown]
# Less but many have a price which we'll keep

# %%
len(physicals["brand"].unique())
# Out:
# 157165

# %%
physicals[physicals["brand"] != ""].count()
# Out:
# category       508712
# description    508712
# fit            508712
# title          508712
# also_buy       508712
# brand          508712
# feature        508712
# rank           508712
# also_view      508712
# main_cat       508712
# price          508712
# asin           508712
# details        508712
# dtype: int64

# %%
physicals["price"].unique()
# Out:
# array(['',
#        '.a-section.a-spacing-mini{margin-bottom:6px!important;margin-top:10px}#actionPanel #availability{font-size:17px!important;font-weight:400!important}#actionPanel #availability p#pa_other_website_text{color:#888!important;margin-top:6px}#actionPanel #merchant-info{font-size:13px;color:#333}#actionPanel #pa_avaliability_message{font-size:12px!important;font-weight:400!important}#actionPanel #pa_avaliability_message a{white-space:normal!important}#actionPanel #pa_avaliability_message span{color:#888!important}#actionPanel #availability-brief #availability+br{display:none}// This is an empty file #actionPanel #bbop-sbbop-container{margin-bottom:0}#actionPanel .buybox-main{padding:0 40px}#actionPanel #priceblock_ourprice_row span.feature img{padding-top:8px!important}#actionPanel #onetimeOption .a-radio-label #priceBadging_feature_div a:not(.a-popover-trigger),#actionPanel #usedOption .a-radio-label #priceBadging_feature_div a:not(.a-popover-trigger){display:none}#actionPanel #pa_feedbackForm_rootmain{text-align:center}.burj #buybox_feature_div #deal #regularBuybox{margin-bottom:14px!important}.burj #hero-quick-promo hr{display:none}#actionPanel #hqp{margin-top:26px}#actionPanel #hqp #amsDetailRight{margin-bottom:18px}#actionPanel #hqp #amsDetailRightWide{margin-bottom:18px}#actionPanel #hqp #hqp-left{margin-bottom:18px}div#hqp-bottom.a-section.burj{margin-bottom:0}.burj #instantOrderUpdate_feature_div',
#        '$5.98', ..., '$86.61', '$101.64', '$85.79'], dtype=object)

# %% [markdown]
# For some reason, there's a lot of values in prices that are just CSS?

# %%
physicals["price"] = physicals["price"].astype('string')

# %%
physicals.dtypes
# Out:
# category       object
# description    object
# fit            object
# title          object
# also_buy       object
# brand          object
# feature        object
# rank           object
# also_view      object
# main_cat       object
# price          string
# asin           object
# details        object
# dtype: object

# %%
physicals[physicals["price"].str.startswith("$")].count()
# Out:
# category       371841
# description    371841
# fit            371841
# title          371841
# also_buy       371841
# brand          371841
# feature        371841
# rank           371841
# also_view      371841
# main_cat       371841
# price          371841
# asin           371841
# details        371841
# dtype: int64

# %%
physicals["price"] = physicals.apply(lambda x: "" if not x["price"].startswith("$") else x["price"], axis=1)

# %%
physicals.head()
# Out:
#                                        category  \
# 0                      [CDs & Vinyl, Christian]
# 1  [CDs & Vinyl, Christian, Pop & Contemporary]
# 2          [CDs & Vinyl, Christian, Children's]
# 3          [CDs & Vinyl, Christian, Children's]
# 4          [CDs & Vinyl, Christian, Children's]
#
#                                          description fit  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [1) To God Be The Glory2) This Is My Fathers W...
# 4  [Joy To The World 2 The First Noel 3 Hark! The...
#
#                                   title  \
# 0                Songs for the Shepherd
# 1       Lift Him Up With Ron Kenoly VHS
# 2                            I Love You
# 3  Hymns: 16 Classic Hymns for Children
# 4                      Christmas Carols
#
#                                             also_buy            brand feature  \
# 0  [B0016CP2GS, B0000075PB, B0000275QQ, B00000I7J...      Keith Green      []
# 1               [6303908845, 6303646611, B000008GO1]                       []
# 2                                                 []  Integrity Music      []
# 3  [B00000DPLJ, B000008UPG, B00BQH9RKA, B00KYVHGR...          Sue Gay      []
# 4                           [B0010WAC50, B00000DPLJ]   Cedarmont Kids      []
#
#                          rank  \
# 0    123,896 in CDs & Vinyl (
# 1    284,935 in Movies & TV (
# 2  1,138,833 in CDs & Vinyl (
# 3    271,064 in CDs & Vinyl (
# 4    409,293 in CDs & Vinyl (
#
#                                            also_view  \
# 0  [B0016CP2GS, B00000I7JO, B00000I9AH, B00P826ZR...
# 1                                       [B00000DUDE]
# 2                                                 []
# 3  [B00000DPLL, 0843113006, B00BQH9RKA, B000008UP...
# 4  [B00000DPKG, B0010WAC50, B00000DPKH, B00FSZPM8...
#
#                                             main_cat price        asin details
# 0  <img src="https://images-na.ssl-images-amazon....        0001393774
# 1                                        Movies & TV        0001501348
# 2  <img src="https://images-na.ssl-images-amazon....        0001515209
# 3  <img src="https://images-na.ssl-images-amazon....        0005072298
# 4  <img src="https://images-na.ssl-images-amazon....        0005121515

# %%
physicals[physicals["price"] != ""].count()
# Out:
# category       371841
# description    371841
# fit            371841
# title          371841
# also_buy       371841
# brand          371841
# feature        371841
# rank           371841
# also_view      371841
# main_cat       371841
# price          371841
# asin           371841
# details        371841
# dtype: int64

# %%
physicals["main_cat"].unique()
# Out:
# array(['<img src="https://images-na.ssl-images-amazon.com/images/G/01/digital/music/logos/amzn_music_logo_subnav._CB471835632_.png" class="nav-categ-image" alt="Digital Music"/>',
#        'Movies & TV',
#        '<img src="https://m.media-amazon.com/images/G/01/digital/music/logos/amzn_music_logo_subnav._CB471835632_.png" class="nav-categ-image" alt="Digital Music"/>',
#        'Books', 'Industrial & Scientific', 'Amazon Home',
#        'Sports & Outdoors', 'Software', 'Home Audio & Theater',
#        'All Electronics', 'All Beauty', 'Musical Instruments',
#        'Toys & Games',
#        '<img src="https://images-na.ssl-images-amazon.com/images/G/01/nav2/images/gui/amazon-fashion-store-new._CB520838675_.png" class="nav-categ-image" alt="AMAZON FASHION"/>',
#        'Cell Phones & Accessories', 'Video Games', 'Office Products',
#        'Health & Personal Care', 'Grocery', 'Baby', 'Pet Supplies',
#        'Tools & Home Improvement', 'Automotive', 'Computers', ''],
#       dtype=object)

# %%
physicals[physicals["main_cat"] != ""].count()
# Out:
# category       516893
# description    516893
# fit            516893
# title          516893
# also_buy       516893
# brand          516893
# feature        516893
# rank           516893
# also_view      516893
# main_cat       516893
# price          516893
# asin           516893
# details        516893
# dtype: int64

# %%
physicals = physicals.replace('<img src="https://images-na.ssl-images-amazon.com/images/G/01/digital/music/logos/amzn_music_logo_subnav._CB471835632_.png" class="nav-categ-image" alt="Digital Music"/>', "Digital Music")

# %%
physicals = physicals.replace('<img src="https://m.media-amazon.com/images/G/01/digital/music/logos/amzn_music_logo_subnav._CB471835632_.png" class="nav-categ-image" alt="Digital Music"/>', "Digital Music")

# %%
physicals = physicals.replace('<img src="https://images-na.ssl-images-amazon.com/images/G/01/nav2/images/gui/amazon-fashion-store-new._CB520838675_.png" class="nav-categ-image" alt="AMAZON FASHION"/>', "AMAZON FASHION")

# %%
physicals["main_cat"].unique()
# Out:
# array(['Digital Music', 'Movies & TV', 'Books', 'Industrial & Scientific',
#        'Amazon Home', 'Sports & Outdoors', 'Software',
#        'Home Audio & Theater', 'All Electronics', 'All Beauty',
#        'Musical Instruments', 'Toys & Games', 'AMAZON FASHION',
#        'Cell Phones & Accessories', 'Video Games', 'Office Products',
#        'Health & Personal Care', 'Grocery', 'Baby', 'Pet Supplies',
#        'Tools & Home Improvement', 'Automotive', 'Computers', ''],
#       dtype=object)

# %%
physicals.groupby("main_cat").count()
# Out:
#                            category  description     fit   title  also_buy  \
# main_cat
#                                  21           21      21      21        21
# AMAZON FASHION                    2            2       2       2         2
# All Beauty                        4            4       4       4         4
# All Electronics                   9            9       9       9         9
# Amazon Home                       2            2       2       2         2
# Automotive                        1            1       1       1         1
# Baby                              4            4       4       4         4
# Books                           222          222     222     222       222
# Cell Phones & Accessories        20           20      20      20        20
# Computers                         2            2       2       2         2
# Digital Music                507239       507239  507239  507239    507239
# Grocery                           6            6       6       6         6
# Health & Personal Care           12           12      12      12        12
# Home Audio & Theater             12           12      12      12        12
# Industrial & Scientific           7            7       7       7         7
# Movies & TV                    9236         9236    9236    9236      9236
# Musical Instruments              43           43      43      43        43
# Office Products                  11           11      11      11        11
# Pet Supplies                      2            2       2       2         2
# Software                         24           24      24      24        24
# Sports & Outdoors                 5            5       5       5         5
# Tools & Home Improvement          5            5       5       5         5
# Toys & Games                     23           23      23      23        23
# Video Games                       2            2       2       2         2
#
#                             brand  feature    rank  also_view   price    asin  \
# main_cat
#                                21       21      21         21      21      21
# AMAZON FASHION                  2        2       2          2       2       2
# All Beauty                      4        4       4          4       4       4
# All Electronics                 9        9       9          9       9       9
# Amazon Home                     2        2       2          2       2       2
# Automotive                      1        1       1          1       1       1
# Baby                            4        4       4          4       4       4
# Books                         222      222     222        222     222     222
# Cell Phones & Accessories      20       20      20         20      20      20
# Computers                       2        2       2          2       2       2
# Digital Music              507239   507239  507239     507239  507239  507239
# Grocery                         6        6       6          6       6       6
# Health & Personal Care         12       12      12         12      12      12
# Home Audio & Theater           12       12      12         12      12      12
# Industrial & Scientific         7        7       7          7       7       7
# Movies & TV                  9236     9236    9236       9236    9236    9236
# Musical Instruments            43       43      43         43      43      43
# Office Products                11       11      11         11      11      11
# Pet Supplies                    2        2       2          2       2       2
# Software                       24       24      24         24      24      24
# Sports & Outdoors               5        5       5          5       5       5
# Tools & Home Improvement        5        5       5          5       5       5
# Toys & Games                   23       23      23         23      23      23
# Video Games                     2        2       2          2       2       2
#
#                            details
# main_cat
#                                 21
# AMAZON FASHION                   2
# All Beauty                       4
# All Electronics                  9
# Amazon Home                      2
# Automotive                       1
# Baby                             4
# Books                          222
# Cell Phones & Accessories       20
# Computers                        2
# Digital Music               507239
# Grocery                          6
# Health & Personal Care          12
# Home Audio & Theater            12
# Industrial & Scientific          7
# Movies & TV                   9236
# Musical Instruments             43
# Office Products                 11
# Pet Supplies                     2
# Software                        24
# Sports & Outdoors                5
# Tools & Home Improvement         5
# Toys & Games                    23
# Video Games                      2

# %%
physicals = physicals.drop(356421)

# %%
physicals = physicals.drop("details", 1)

# %%
physicals["category"] = physicals["category"].apply(', '.join)

# %%
physicals["description"] = physicals["description"].apply(', '.join)

# %%
physicals["also_buy"] = physicals["also_buy"].apply(', '.join)

# %%
physicals["feature"] = physicals["feature"].apply(', '.join)

# %%
physicals["also_view"] = physicals["also_view"].apply(', '.join)

# %%
physicals.head()
# Out:
#                                      category  \
# 0                      CDs & Vinyl, Christian
# 1  CDs & Vinyl, Christian, Pop & Contemporary
# 2          CDs & Vinyl, Christian, Children's
# 3          CDs & Vinyl, Christian, Children's
# 4          CDs & Vinyl, Christian, Children's
#
#                                          description fit  \
# 0
# 1
# 2
# 3  1) To God Be The Glory2) This Is My Fathers Wo...
# 4  Joy To The World 2 The First Noel 3 Hark! The ...
#
#                                   title  \
# 0                Songs for the Shepherd
# 1       Lift Him Up With Ron Kenoly VHS
# 2                            I Love You
# 3  Hymns: 16 Classic Hymns for Children
# 4                      Christmas Carols
#
#                                             also_buy            brand feature  \
# 0  B0016CP2GS, B0000075PB, B0000275QQ, B00000I7JO...      Keith Green
# 1                 6303908845, 6303646611, B000008GO1
# 2                                                     Integrity Music
# 3  B00000DPLJ, B000008UPG, B00BQH9RKA, B00KYVHGR0...          Sue Gay
# 4                             B0010WAC50, B00000DPLJ   Cedarmont Kids
#
#                          rank  \
# 0    123,896 in CDs & Vinyl (
# 1    284,935 in Movies & TV (
# 2  1,138,833 in CDs & Vinyl (
# 3    271,064 in CDs & Vinyl (
# 4    409,293 in CDs & Vinyl (
#
#                                            also_view       main_cat price  \
# 0  B0016CP2GS, B00000I7JO, B00000I9AH, B00P826ZRM...  Digital Music
# 1                                         B00000DUDE    Movies & TV
# 2                                                     Digital Music
# 3  B00000DPLL, 0843113006, B00BQH9RKA, B000008UPI...  Digital Music
# 4  B00000DPKG, B0010WAC50, B00000DPKH, B00FSZPM8C...  Digital Music
#
#          asin
# 0  0001393774
# 1  0001501348
# 2  0001515209
# 3  0005072298
# 4  0005121515

# %%
physicals = physicals.drop('fit', 1)

# %%
physicals = physicals.astype(str)

# %%
physicals = physicals.drop_duplicates()

# %%
len(physicals)
# Out:
# 412324

# %% [markdown]
# A lot of duplicates have been removed. We originally had 516914 products

# %% [markdown]
# Below I just used this piece of code for every main category to strip off any non-music related items.
#
# physicals[physicals["main_cat"] == "AMAZON FASHION"]

# %%
physicals = physicals.drop(365939)

# %%
physicals = physicals.drop(319684)

# %%
physicals = physicals.drop(319692)

# %%
physicals = physicals.drop(105483)

# %%
physicals = physicals.drop(188413)

# %%
physicals = physicals.drop(353431)

# %%
physicals = physicals.drop(179820)

# %%
physicals = physicals.drop(38686)

# %%
physicals = physicals.drop(320398)

# %%
physicals = physicals.drop(383672)

# %%
physicals = physicals.drop(505573)

# %%
physicals = physicals.drop(106364)

# %%
physicals = physicals.drop(352605)

# %%
physicals = physicals.drop(415091)

# %%
physicals = physicals.drop(415094)

# %%
physicals = physicals.drop(126624)

# %%
physicals = physicals[physicals["main_cat"] != "AMAZON FASHION"]

# %%
physicals = physicals[physicals["main_cat"] != "Pet Supplies"]

# %%
physicals = physicals[physicals["main_cat"] != "All Beauty"]

# %%
physicals = physicals[physicals["main_cat"] != "Books"]

# %%
physicals = physicals[physicals["main_cat"] != "Computers"]

# %%
physicals = physicals[physicals["main_cat"] != "Grocery"]

# %%
physicals = physicals[physicals["main_cat"] != "Software"]

# %%
physicals.groupby("main_cat").count()
# Out:
#                            category  description   title  also_buy   brand  \
# main_cat
#                                  21           21      21        21      21
# All Electronics                   8            8       8         8       8
# Amazon Home                       2            2       2         2       2
# Baby                              2            2       2         2       2
# Cell Phones & Accessories        16           16      16        16      16
# Digital Music                404814       404814  404814    404814  404814
# Health & Personal Care            9            9       9         9       9
# Home Audio & Theater              7            7       7         7       7
# Industrial & Scientific           6            6       6         6       6
# Movies & TV                    7105         7105    7105      7105    7105
# Musical Instruments              43           43      43        43      43
# Office Products                   9            9       9         9       9
# Sports & Outdoors                 4            4       4         4       4
# Tools & Home Improvement          5            5       5         5       5
# Toys & Games                     18           18      18        18      18
#
#                            feature    rank  also_view   price    asin
# main_cat
#                                 21      21         21      21      21
# All Electronics                  8       8          8       8       8
# Amazon Home                      2       2          2       2       2
# Baby                             2       2          2       2       2
# Cell Phones & Accessories       16      16         16      16      16
# Digital Music               404814  404814     404814  404814  404814
# Health & Personal Care           9       9          9       9       9
# Home Audio & Theater             7       7          7       7       7
# Industrial & Scientific          6       6          6       6       6
# Movies & TV                   7105    7105       7105    7105    7105
# Musical Instruments             43      43         43      43      43
# Office Products                  9       9          9       9       9
# Sports & Outdoors                4       4          4       4       4
# Tools & Home Improvement         5       5          5       5       5
# Toys & Games                    18      18         18      18      18

# %% [markdown]
# The main categories were useful for cleaning up but they are usually misleading and the distribution doesn't show that it will provide meaningful insignts since most of them are in the Digital Music section.

# %%
physicals = physicals.drop("main_cat", 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-303-f731d8b2a4c1> in <module>
# ----> 1 physicals = physicals.drop("main_cat", 1)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['main_cat'] not found in axis"

# %%
physicals.head()
# Out:
#                                      category  \
# 0                      CDs & Vinyl, Christian
# 1  CDs & Vinyl, Christian, Pop & Contemporary
# 2          CDs & Vinyl, Christian, Children's
# 3          CDs & Vinyl, Christian, Children's
# 4          CDs & Vinyl, Christian, Children's
#
#                                          description  \
# 0
# 1
# 2
# 3  1) To God Be The Glory2) This Is My Fathers Wo...
# 4  Joy To The World 2 The First Noel 3 Hark! The ...
#
#                                   title  \
# 0                Songs for the Shepherd
# 1       Lift Him Up With Ron Kenoly VHS
# 2                            I Love You
# 3  Hymns: 16 Classic Hymns for Children
# 4                      Christmas Carols
#
#                                             also_buy            brand feature  \
# 0  B0016CP2GS, B0000075PB, B0000275QQ, B00000I7JO...      Keith Green
# 1                 6303908845, 6303646611, B000008GO1
# 2                                                     Integrity Music
# 3  B00000DPLJ, B000008UPG, B00BQH9RKA, B00KYVHGR0...          Sue Gay
# 4                             B0010WAC50, B00000DPLJ   Cedarmont Kids
#
#                          rank  \
# 0    123,896 in CDs & Vinyl (
# 1    284,935 in Movies & TV (
# 2  1,138,833 in CDs & Vinyl (
# 3    271,064 in CDs & Vinyl (
# 4    409,293 in CDs & Vinyl (
#
#                                            also_view price        asin
# 0  B0016CP2GS, B00000I7JO, B00000I9AH, B00P826ZRM...        0001393774
# 1                                         B00000DUDE        0001501348
# 2                                                           0001515209
# 3  B00000DPLL, 0843113006, B00BQH9RKA, B000008UPI...        0005072298
# 4  B00000DPKG, B0010WAC50, B00000DPKH, B00FSZPM8C...        0005121515

# %%
len(physicals)
# Out:
# 412069

# %%
physicals["category"].unique()
# Out:
# array(['CDs & Vinyl, Christian',
#        'CDs & Vinyl, Christian, Pop & Contemporary',
#        "CDs & Vinyl, Christian, Children's",
#        'CDs & Vinyl, Holiday & Wedding', 'CDs & Vinyl, Special Interest',
#        'CDs & Vinyl, Jazz',
#        'CDs & Vinyl, Comedy & Spoken Word, Spoken Word',
#        'CDs & Vinyl, World Music, Europe, British Isles, Britain',
#        'CDs & Vinyl, Soundtracks', 'CDs & Vinyl, New Age, Meditation',
#        'CDs & Vinyl, Special Interest, Instructional',
#        "CDs & Vinyl, Children's Music, Lullabies",
#        'CDs & Vinyl, Holiday & Wedding, Christmas',
#        'CDs & Vinyl, World Music', 'CDs & Vinyl, Rock, Rock Guitarists',
#        'CDs & Vinyl, Classic Rock, British Invasion',
#        'CDs & Vinyl, World Music, Europe, British Isles, Ireland',
#        'CDs & Vinyl, Broadway & Vocalists, Musicals',
#        'CDs & Vinyl, New Age', 'CDs & Vinyl, Pop, Vocal Pop',
#        'CDs & Vinyl, Classical', 'CDs & Vinyl, Comedy & Spoken Word',
#        "CDs & Vinyl, Children's Music, Educational",
#        'CDs & Vinyl, Folk, Contemporary Folk',
#        'CDs & Vinyl, Special Interest, Radio Shows',
#        'CDs & Vinyl, New Age, Relaxation',
#        "CDs & Vinyl, Children's Music",
#        "CDs & Vinyl, Children's Music, Stories",
#        'CDs & Vinyl, Classical, Symphonies',
#        'CDs & Vinyl, Pop, Dance Pop',
#        'CDs & Vinyl, Soundtracks, Movie Soundtracks',
#        'CDs & Vinyl, R&B, Soul',
#        'CDs & Vinyl, Alternative Rock, Hardcore & Punk, American Punk',
#        'CDs & Vinyl, Classic Rock, Album-Oriented Rock (AOR)',
#        'CDs & Vinyl, Opera & Classical Vocal',
#        'CDs & Vinyl, Pop, Oldies, Traditional Pop',
#        'CDs & Vinyl, Jazz, Avant Garde & Free Jazz',
#        'CDs & Vinyl, Comedy & Spoken Word, Poetry',
#        'CDs & Vinyl, Jazz, Bebop',
#        'CDs & Vinyl, World Music, Middle East, Islamic',
#        'CDs & Vinyl, Folk, Traditional Folk',
#        'CDs & Vinyl, Special Interest, Exercise',
#        'CDs & Vinyl, World Music, South & Central America',
#        'CDs & Vinyl, Rock',
#        'CDs & Vinyl, Alternative Rock, New Wave & Post-Punk, New Wave',
#        'CDs & Vinyl, Rock, Hard Rock',
#        'CDs & Vinyl, Classic Rock, Southern Rock',
#        'CDs & Vinyl, Rock, Progressive, Progressive Rock',
#        'CDs & Vinyl, Folk', 'CDs & Vinyl, New Age, Healing',
#        'CDs & Vinyl, Folk, British & Celtic Folk, Irish Folk',
#        "CDs & Vinyl, Country, Today's Country",
#        'CDs & Vinyl, Pop, Oldies',
#        'CDs & Vinyl, Special Interest, Self-Help',
#        'CDs & Vinyl, World Music, Middle East', 'CDs & Vinyl, Pop',
#        'CDs & Vinyl, World Music, Caribbean & Cuba', 'CDs & Vinyl, Blues',
#        'CDs & Vinyl, Country, Bluegrass', 'CDs & Vinyl, Jazz, Jive Jazz',
#        'CDs & Vinyl, Alternative Rock, Indie & Lo-Fi, Indie Rock',
#        'CDs & Vinyl, Alternative Rock, Hardcore & Punk, Punk',
#        'CDs & Vinyl, Pop, Easy Listening',
#        'CDs & Vinyl, Pop, Oldies, Baroque Pop',
#        'CDs & Vinyl, Rap & Hip-Hop', 'CDs & Vinyl, Karaoke',
#        'CDs & Vinyl, Jazz, Vocal Jazz', 'CDs & Vinyl, Country',
#        'CDs & Vinyl, Rap & Hip-Hop, East Coast',
#        'CDs & Vinyl, Christian, Instrumental',
#        'CDs & Vinyl, Holiday & Wedding, Easter',
#        'CDs & Vinyl, Rap & Hip-Hop, Pop Rap',
#        'CDs & Vinyl, World Music, Europe, Continental Europe',
#        'CDs & Vinyl, World Music, North America, Native American',
#        'CDs & Vinyl, Christian, Rap & Hip-Hop', 'CDs & Vinyl, R&B, Funk',
#        'CDs & Vinyl, Comedy & Spoken Word, Comedic Music',
#        'CDs & Vinyl, Jazz, Swing Jazz, Classic Big Band',
#        "CDs & Vinyl, Children's Music, Disney",
#        'CDs & Vinyl, Pop, Adult Alternative',
#        'CDs & Vinyl, Pop, Adult Contemporary',
#        'CDs & Vinyl, Classical, Chamber Music',
#        'CDs & Vinyl, Rock, Blues Rock',
#        'CDs & Vinyl, Pop, Singer-Songwriters',
#        'CDs & Vinyl, Rock, Country Rock', 'CDs & Vinyl, Jazz, Swing Jazz',
#        'CDs & Vinyl, Folk, British & Celtic Folk, British Folk',
#        'CDs & Vinyl, Gospel', 'CDs & Vinyl, Metal, Thrash & Speed Metal',
#        'CDs & Vinyl, Rap & Hip-Hop, Experimental Rap',
#        'CDs & Vinyl, Pop, Soft Rock',
#        'CDs & Vinyl, Alternative Rock, Hardcore & Punk, Hardcore',
#        'CDs & Vinyl, Rock, Folk Rock',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Jamaica',
#        'CDs & Vinyl, Blues, Electric Blues',
#        "CDs & Vinyl, Children's Music, Sing-A-Longs",
#        'CDs & Vinyl, Pop, Oldies, Doo Wop', 'CDs & Vinyl, Reggae, Dub',
#        'CDs & Vinyl, Jazz, Soul-Jazz & Boogaloo',
#        'CDs & Vinyl, R&B, Contemporary R&B',
#        'CDs & Vinyl, Blues, Regional Blues, Texas Blues',
#        'CDs & Vinyl, Metal, Pop Metal',
#        'CDs & Vinyl, World Music, Africa, Nigeria',
#        'CDs & Vinyl, Country, Roadhouse Country',
#        'CDs & Vinyl, Alternative Rock, Goth & Industrial, Industrial, Alt Industrial',
#        'CDs & Vinyl, Alternative Rock, Indie & Lo-Fi, Jangle Pop',
#        'CDs & Vinyl, Metal, Alternative Metal',
#        'CDs & Vinyl, Alternative Rock, New Wave & Post-Punk, Post-Punk',
#        'CDs & Vinyl, Alternative Rock, Hardcore & Punk, Proto Punk',
#        'CDs & Vinyl, Blues, Contemporary Blues',
#        'CDs & Vinyl, World Music, Far East & Asia',
#        'CDs & Vinyl, Blues, Vocal Blues',
#        'CDs & Vinyl, Classical, Forms & Genres, Short Forms, Nocturnes',
#        'CDs & Vinyl, Rock, Progressive, Progressive Metal',
#        'CDs & Vinyl, Alternative Rock, Hardcore & Punk, British Punk',
#        'CDs & Vinyl, Dance & Electronic, Electronica',
#        'CDs & Vinyl, World Music, Europe, Scandinavia, Sweden',
#        'CDs & Vinyl, Country, Classic Country',
#        'CDs & Vinyl, Country, Outlaw Country',
#        'CDs & Vinyl, Pop, Euro Pop, Swedish Pop',
#        'CDs & Vinyl, Soundtracks, Movie Scores',
#        'CDs & Vinyl, Pop, Tributes',
#        'CDs & Vinyl, Country, Classic Country, Nashville Sound',
#        'CDs & Vinyl, Alternative Rock, Indie & Lo-Fi, Dream Pop',
#        'CDs & Vinyl, Dance & Electronic, Disco',
#        'CDs & Vinyl, World Music, Pacific Islands, Tahiti',
#        'CDs & Vinyl, Blues, Regional Blues, West Coast Blues',
#        'CDs & Vinyl, Jazz, Jazz Fusion',
#        'CDs & Vinyl, World Music, Europe, Eastern Europe, Polka',
#        'CDs & Vinyl, New Age, Nature & Environment',
#        'CDs & Vinyl, Country, Classic Country, Old-Time Country',
#        'CDs & Vinyl, World Music, Pacific Islands, Hawaii',
#        'CDs & Vinyl, Classic Rock, Psychedelic Rock',
#        'CDs & Vinyl, Alternative Rock, Goth & Industrial, Goth',
#        'CDs & Vinyl, Latin Music, Tejano',
#        'CDs & Vinyl, Classic Rock, Arena Rock',
#        'CDs & Vinyl, Christian, Praise & Worship',
#        'CDs & Vinyl, World Music, Africa',
#        'CDs & Vinyl, Blues, Regional Blues, Chicago Blues',
#        'CDs & Vinyl, Blues, Traditional Blues',
#        'CDs & Vinyl, Blues, Regional Blues, Delta Blues',
#        'CDs & Vinyl, Alternative Rock, British Alternative, Britpop',
#        'CDs & Vinyl, Latin Music, Latin Pop',
#        'CDs & Vinyl, Alternative Rock, American Alternative',
#        'CDs & Vinyl, Rock, Power Pop',
#        'CDs & Vinyl, Holiday & Wedding, Halloween',
#        'CDs & Vinyl, World Music, India & Pakistan',
#        'CDs & Vinyl, Rock, Oldies & Retro, Rockabilly',
#        'CDs & Vinyl, Alternative Rock, Hardcore & Punk, Ska Punk',
#        'CDs & Vinyl, World Music, Europe, Continental Europe, Denmark',
#        'CDs & Vinyl, Alternative Rock, Hardcore & Punk, Punk Revival',
#        'CDs & Vinyl, World Music, Europe, Continental Europe, Italy',
#        'CDs & Vinyl, World Music, Europe, Continental Europe, Germany',
#        'CDs & Vinyl, Jazz, Latin Jazz',
#        'CDs & Vinyl, Blues, Regional Blues, Cajun & Zydeco',
#        'CDs & Vinyl, Rock, Roots Rock',
#        'CDs & Vinyl, Rap & Hip-Hop, Gangsta & Hardcore',
#        'CDs & Vinyl, New Age, Celtic New Age',
#        'CDs & Vinyl, Pop, Oldies, Bubblegum',
#        'CDs & Vinyl, Christian, Southern Gospel',
#        'CDs & Vinyl, Reggae, Dance Hall',
#        'CDs & Vinyl, Classical, Forms & Genres, Sonatas, Sonatinas',
#        'CDs & Vinyl, Alternative Rock, Hardcore & Punk, Post Hardcore',
#        'CDs & Vinyl, R&B, New Jack',
#        'CDs & Vinyl, World Music, Africa, Senegal & Gambia',
#        'CDs & Vinyl, World Music, Far East & Asia, Indonesia',
#        'CDs & Vinyl, Dance & Electronic, Trip-Hop',
#        'CDs & Vinyl, Alternative Rock, Hardcore & Punk, Punk-Pop',
#        'CDs & Vinyl, Rock, Rap Rock', 'CDs & Vinyl, Country, Americana',
#        'CDs & Vinyl, Christian, Rock & Alternative',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Noels',
#        'CDs & Vinyl, Rock, Progressive, Electronic',
#        'CDs & Vinyl, World Music, Far East & Asia, China',
#        'CDs & Vinyl, Alternative Rock',
#        'CDs & Vinyl, World Music, Far East & Asia, Japan',
#        'CDs & Vinyl, World Music, Australia & New Zealand',
#        'CDs & Vinyl, Soundtracks, Television Soundtracks',
#        'CDs & Vinyl, Classic Rock', 'CDs & Vinyl, Latin Music, Tango',
#        'CDs & Vinyl, World Music, South & Central America, Brazil',
#        'CDs & Vinyl, Dance & Electronic, World Dance',
#        'CDs & Vinyl, Classical, Forms & Genres, Concertos',
#        'CDs & Vinyl, Dance & Electronic',
#        'CDs & Vinyl, Dance & Electronic, Techno',
#        'CDs & Vinyl, Gospel, Urban & Contemporary',
#        'CDs & Vinyl, World Music, Middle East, Iran',
#        'CDs & Vinyl, Classical, Forms & Genres, Etudes',
#        'CDs & Vinyl, Classical, Forms & Genres, Serenades & Divertimentos',
#        'CDs & Vinyl, Classical, Ballets & Dances, Ballets',
#        'CDs & Vinyl, Classical, Forms & Genres, Sonatas',
#        'CDs & Vinyl, Classical, Forms & Genres, Theatrical, Incidental & Program Music',
#        'CDs & Vinyl, World Music, Far East & Asia, Russia',
#        'CDs & Vinyl, Jazz, Traditional Jazz & Ragtime',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Lullabies & Berceuse',
#        'CDs & Vinyl, World Music, Europe, Eastern Europe, Poland',
#        'CDs & Vinyl, Dance & Electronic, Freestyle',
#        'CDs & Vinyl, Dance & Electronic, Ambient',
#        'CDs & Vinyl, Dance & Electronic, House',
#        'CDs & Vinyl, R&B, Soul, Blue-Eyed Soul',
#        'CDs & Vinyl, Rock, Oldies & Retro, Surf Rock',
#        'CDs & Vinyl, World Music, Europe, Eastern Europe, Hungary',
#        'CDs & Vinyl, Rock, Rock Guitarists, Shred',
#        'CDs & Vinyl, World Music, South & Central America, Andes',
#        'CDs & Vinyl, Latin Music, Norteo',
#        'CDs & Vinyl, Country, Classic Country, Bakersfield Sound',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Cuba, Bolero',
#        'CDs & Vinyl, Blues, Acoustic Blues',
#        'CDs & Vinyl, Blues, Regional Blues, New Orleans Blues',
#        'CDs & Vinyl, Blues, Slide Guitar', 'CDs & Vinyl, Jazz, Acid Jazz',
#        'CDs & Vinyl, Jazz, Dixieland', 'CDs & Vinyl, Jazz, Smooth Jazz',
#        'CDs & Vinyl, Alternative Rock, Indie & Lo-Fi',
#        'CDs & Vinyl, Broadway & Vocalists, Traditional Vocal Pop',
#        'CDs & Vinyl, World Music, South & Central America, Peru',
#        'CDs & Vinyl, Jazz, Cool Jazz',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Cuba',
#        'CDs & Vinyl, Blues, Piano Blues',
#        'CDs & Vinyl, Blues, Regional Blues, Memphis Blues',
#        'CDs & Vinyl, Country, Cowboy',
#        'CDs & Vinyl, World Music, North America, Appalachian',
#        'CDs & Vinyl, Folk, British & Celtic Folk, Celtic Folk',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Calypso',
#        'CDs & Vinyl, World Music, Europe, Continental Europe, Greece',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Cuba, Mambo',
#        'CDs & Vinyl, World Music, Middle East, Turkey',
#        'CDs & Vinyl, Jazz, New Orleans Jazz',
#        'CDs & Vinyl, World Music, Europe, Continental Europe, France',
#        'CDs & Vinyl, Jazz, Swing Jazz, Contemporary Big Band',
#        'CDs & Vinyl, World Music, Africa, South Africa',
#        'CDs & Vinyl, World Music, Africa, Congo',
#        'CDs & Vinyl, World Music, Africa, Algeria',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Puerto Rico',
#        'CDs & Vinyl, World Music, Africa, Ghana',
#        'CDs & Vinyl, World Music, Africa, Tanzania',
#        'CDs & Vinyl, World Music, South & Central America, Nicaragua',
#        'CDs & Vinyl, Reggae, Rocksteady',
#        'CDs & Vinyl, Alternative Rock, Ska', 'CDs & Vinyl, Reggae',
#        'CDs & Vinyl, R&B, Soul, Memphis Soul',
#        'CDs & Vinyl, Alternative Rock, Hardcore & Punk, Emo',
#        'CDs & Vinyl, Rock, Jam Bands',
#        'CDs & Vinyl, Rap & Hip-Hop, Old School',
#        'CDs & Vinyl, Jazz, Traditional Jazz & Ragtime, Stride Piano',
#        'CDs & Vinyl, Christian, Country & Bluegrass',
#        'CDs & Vinyl, Classical, Forms & Genres, Concertos, Concerto Grossi',
#        'CDs & Vinyl, Metal',
#        'CDs & Vinyl, Classical, Forms & Genres, Short Forms, Character Pieces',
#        'CDs & Vinyl, Metal, British Metal',
#        'CDs & Vinyl, World Music, Europe, Eastern Europe, Bulgaria',
#        'CDs & Vinyl, World Music, South & Central America, Bolivia',
#        'CDs & Vinyl, World Music, South & Central America, Brazil, Bossa Nova',
#        'CDs & Vinyl, World Music, Africa, Cameroon',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Cuba, Salsa',
#        'CDs & Vinyl, Classical, Forms & Genres, Preludes',
#        'CDs & Vinyl, Classical, Forms & Genres, Suites',
#        'CDs & Vinyl, Classical, Ballets & Dances, Waltzes',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Songs & Lieder, Folk Songs',
#        'CDs & Vinyl, Classical, Forms & Genres, Theatrical, Incidental & Program Music, Marches',
#        'CDs & Vinyl, Classical, Forms & Genres, Theatrical, Incidental & Program Music, Tone Poems',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Anthems',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Cantatas',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Masses',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Hymns',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Odes',
#        'CDs & Vinyl, World Music, Middle East, Israel',
#        'CDs & Vinyl, Classical, Forms & Genres, Theatrical, Incidental & Program Music, Incidental Music',
#        'CDs & Vinyl, Classical, Sacred & Religious',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Oratorios',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Motets',
#        'CDs & Vinyl, Classical, Forms & Genres, Sonatas, Canzones',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Songs & Lieder, Madrigals',
#        'CDs & Vinyl, Classical, Ballets & Dances, Baroque Dance Suites',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Passions',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Chansons',
#        'CDs & Vinyl, Opera & Classical Vocal, Arias',
#        'CDs & Vinyl, Classical, Ballets & Dances, Ecossaises',
#        'CDs & Vinyl, Folk, Jewish & Yiddish',
#        'CDs & Vinyl, World Music, Far East & Asia, Tibet',
#        'CDs & Vinyl, World Music, Europe, Eastern Europe, Armenia',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Magnificats',
#        'CDs & Vinyl, Classical, Forms & Genres, Requiems, Elegies & Tombeau, Elegies',
#        'CDs & Vinyl, World Music, Far East & Asia, Vietnam',
#        'CDs & Vinyl, World Music, Europe, Continental Europe, Netherlands',
#        'CDs & Vinyl, Pop, Oldies, Girl Groups',
#        'CDs & Vinyl, Blues, Regional Blues, East Coast Blues',
#        'CDs & Vinyl, R&B, Soul, Southern Soul',
#        'CDs & Vinyl, Classic Rock, Glam',
#        'CDs & Vinyl, Jazz, Traditional Jazz & Ragtime, Boogie-Woogie',
#        'CDs & Vinyl, R&B, Soul, Northern',
#        'CDs & Vinyl, Blues, Jump Blues',
#        'CDs & Vinyl, R&B, Soul, Philly Soul',
#        'CDs & Vinyl, Comedy & Spoken Word, Stand-Up Comedy',
#        'CDs & Vinyl, Dance & Electronic, Drum & Bass',
#        'CDs & Vinyl, World Music, Africa, Egypt',
#        'CDs & Vinyl, Alternative Rock, New Wave & Post-Punk, Urban Folk',
#        'CDs & Vinyl, Rock, Oldies & Retro',
#        'CDs & Vinyl, Classical, Forms & Genres, Variations, Passacaglias',
#        'CDs & Vinyl, Classical, Forms & Genres, Canons',
#        'CDs & Vinyl, Classical, Ballets & Dances, Baroque Dance Suites, Sarabande',
#        'CDs & Vinyl, Classical, Ballets & Dances, Pavanes',
#        'CDs & Vinyl, Classical, Forms & Genres, Fantasies',
#        'CDs & Vinyl, Classical, Forms & Genres, Theatrical, Incidental & Program Music, Overtures',
#        'CDs & Vinyl, Classical, Forms & Genres, Ballads',
#        'CDs & Vinyl, Classical, Ballets & Dances, Dances',
#        'CDs & Vinyl, World Music, Europe, Scandinavia',
#        'CDs & Vinyl, Classical, Forms & Genres, Rondos',
#        'CDs & Vinyl, Opera & Classical Vocal, Operettas',
#        'CDs & Vinyl, Classical, Forms & Genres, Requiems, Elegies & Tombeau',
#        'CDs & Vinyl, Classical, Forms & Genres, Variations',
#        'CDs & Vinyl, Classical, Forms & Genres, Concertos, Concertinos',
#        'CDs & Vinyl, Alternative Rock, Goth & Industrial',
#        'CDs & Vinyl, World Music, Europe, Eastern Europe, Romania',
#        'CDs & Vinyl, Jazz, Traditional Jazz & Ragtime, Ragtime',
#        'CDs & Vinyl, World Music, Middle East, Arabic',
#        'CDs & Vinyl, Classical, Ballets & Dances, Polkas',
#        'CDs & Vinyl, World Music, South & Central America, Argentina',
#        'CDs & Vinyl, World Music, Europe, Continental Europe, Spain',
#        'CDs & Vinyl, Alternative Rock, Ska, Third Wave Ska',
#        'CDs & Vinyl, World Music, Africa, Ivory Coast',
#        'CDs & Vinyl, World Music, Europe, Scandinavia, Norway',
#        'CDs & Vinyl, World Music, Africa, Madagascar',
#        'CDs & Vinyl, World Music, Africa, Zimbabwe',
#        'CDs & Vinyl, Comedy & Spoken Word, Country Comedy',
#        'CDs & Vinyl, Classical, Forms & Genres, Fugues',
#        'CDs & Vinyl, Dance & Electronic, Turntablists',
#        'CDs & Vinyl, Rap & Hip-Hop, Bass',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Cuba, Charanga',
#        'CDs & Vinyl, World Music, South & Central America, Brazil, Afro Brazilian',
#        'CDs & Vinyl, World Music, Africa, Morocco',
#        'CDs & Vinyl, Alternative Rock, Goth & Industrial, Industrial, Industrial Dance',
#        'CDs & Vinyl, Alternative Rock, Hardcore & Punk, Straight Edge',
#        'CDs & Vinyl, Metal, Death Metal',
#        'CDs & Vinyl, Metal, Black Metal',
#        'CDs & Vinyl, Alternative Rock, Goth & Industrial, Industrial',
#        'CDs & Vinyl, Rap & Hip-Hop, West Coast',
#        'CDs & Vinyl, World Music, Africa, Guinea',
#        'CDs & Vinyl, World Music, Europe, Eastern Europe',
#        'CDs & Vinyl, Alternative Rock, Indie & Lo-Fi, Ambient Pop',
#        'CDs & Vinyl, World Music, Europe, Eastern Europe, Gypsy',
#        'CDs & Vinyl, Alternative Rock, Singer-Songwriters',
#        'CDs & Vinyl, World Music, Europe, Continental Europe, Belgium',
#        'CDs & Vinyl, Rock, Rock Guitarists, Guitar Gods',
#        'CDs & Vinyl, R&B', 'CDs & Vinyl, Latin Music, Flamenco',
#        'CDs & Vinyl, World Music, North America',
#        'CDs & Vinyl, Blues, Harmonica Blues',
#        'CDs & Vinyl, World Music, South & Central America, El Salvador',
#        'CDs & Vinyl, New Age, Instrumental',
#        'CDs & Vinyl, Pop, Euro Pop, French Pop',
#        'CDs & Vinyl, R&B, Quiet Storm',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Trinidad',
#        'CDs & Vinyl, Reggae, Jamaican Ska',
#        'CDs & Vinyl, Dance & Electronic, Big Beat',
#        'CDs & Vinyl, Jazz, Swing Jazz, Vintage Dance Bands',
#        'CDs & Vinyl, Classical, Ballets & Dances, Tangos',
#        'CDs & Vinyl, Classical, Ballets & Dances, Baroque Dance Suites, Gigue',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Requiems',
#        'CDs & Vinyl, Country, Western Swing',
#        'CDs & Vinyl, Classical, Forms & Genres, Short Forms, Impromptus',
#        'CDs & Vinyl, Classical, Forms & Genres, Short Forms',
#        'CDs & Vinyl, Classical, Chamber Music, Trios',
#        'CDs & Vinyl, Classical, Forms & Genres, Sonatas, Trio Sonatas',
#        'CDs & Vinyl, World Music, South & Central America, Chile',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Songs & Lieder',
#        'CDs & Vinyl, R&B, Classic R&B',
#        'CDs & Vinyl, Holiday & Wedding, Wedding Music',
#        'CDs & Vinyl, Latin Music, Mariachi',
#        'CDs & Vinyl, World Music, South & Central America, Colombia',
#        'CDs & Vinyl, Latin Music, Salsa',
#        'CDs & Vinyl, Alternative Rock, New Wave & Post-Punk',
#        'CDs & Vinyl, Alternative Rock, Indie & Lo-Fi, Shoegazing',
#        'CDs & Vinyl, Latin Music, Latin Hip-Hop',
#        'CDs & Vinyl, World Music, Europe, British Isles, Scotland',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Partsongs',
#        'CDs & Vinyl, Classical, Ballets & Dances, Baroque Dance Suites, Allemandes',
#        'CDs & Vinyl, Classical, Chamber Music, Quintets',
#        'CDs & Vinyl, Opera & Classical Vocal, Voices',
#        'CDs & Vinyl, Jazz, Modern Postbebop',
#        'CDs & Vinyl, Blues, Regional Blues, St. Louis Blues',
#        'CDs & Vinyl, Blues, Regional Blues, New York Blues',
#        'CDs & Vinyl, World Music, Europe, Eastern Europe, Ukraine',
#        'CDs & Vinyl, Comedy & Spoken Word, Interviews',
#        'CDs & Vinyl, Latin Music, Merengue',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Cuba, Big Band',
#        'CDs & Vinyl, Classical, Forms & Genres, Inventions',
#        'CDs & Vinyl, World Music, Europe, Continental Europe, Austria',
#        'CDs & Vinyl, Classical, Ballets & Dances, Minuets',
#        'CDs & Vinyl, Classical, Ballets & Dances, Mazurkas',
#        'CDs & Vinyl, Classical, Ballets & Dances, Polonaises',
#        'CDs & Vinyl, Classical, Chamber Music, Quartets',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Chants',
#        'CDs & Vinyl, Classical, Forms & Genres, Improvisation',
#        'CDs & Vinyl, Classical, Sacred & Religious, Voluntaries',
#        'CDs & Vinyl, Classical, Forms & Genres, Variations, Grounds',
#        'CDs & Vinyl, Opera & Classical Vocal, Oratorios',
#        'CDs & Vinyl, World Music, Europe, Eastern Europe, Czech Republic',
#        'CDs & Vinyl, Blues, Regional Blues, Detroit Blues',
#        'CDs & Vinyl, Broadway & Vocalists, Classic Vocalists',
#        'CDs & Vinyl, Broadway & Vocalists, Cabaret',
#        'CDs & Vinyl, Alternative Rock, Hardcore & Punk, Garage Punk',
#        'CDs & Vinyl, Special Interest, Sound Effects',
#        'CDs & Vinyl, Latin Music, Latin Rock',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Zouk',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Dominican Republic',
#        'CDs & Vinyl, Classical, Forms & Genres, Toccatas',
#        'CDs & Vinyl, Pop, Oldies, Tin Pan Alley',
#        'CDs & Vinyl, Alternative Rock, Indie & Lo-Fi, Riot Grrl',
#        'CDs & Vinyl, Gospel, Choir',
#        'CDs & Vinyl, Alternative Rock, Indie & Lo-Fi, Lo-Fi',
#        'CDs & Vinyl, R&B, Motown', 'CDs & Vinyl, Pop, Teen Pop',
#        'CDs & Vinyl, Christian, Hard Rock & Metal',
#        'CDs & Vinyl, Latin Music, Banda',
#        'CDs & Vinyl, Latin Music, Bachata',
#        'CDs & Vinyl, Jazz, Swing Jazz, Retro Swing',
#        'CDs & Vinyl, Alternative Rock, British Alternative',
#        'CDs & Vinyl, World Music, Europe, Continental Europe, Switzerland',
#        'CDs & Vinyl, Dance & Electronic, Trance',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Haiti',
#        'CDs & Vinyl, World Music, Europe, Continental Europe, Portugal',
#        'CDs & Vinyl, Comedy & Spoken Word, Shock Comedy',
#        'CDs & Vinyl, World Music, South & Central America, Uruguay',
#        'CDs & Vinyl, Alternative Rock, Indie & Lo-Fi, Chamber Pop',
#        'CDs & Vinyl, R&B, Neo-Soul',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Bahamas',
#        'CDs & Vinyl, Rock, Funk Rock', 'CDs & Vinyl, World Music, Europe',
#        'CDs & Vinyl, World Music, Pacific Islands, Polynesian Music',
#        'CDs & Vinyl, World Music, Europe, Scandinavia, Finland',
#        'CDs & Vinyl, World Music, Far East & Asia, Korea',
#        'CDs & Vinyl, Folk, British & Celtic Folk, Scottish Folk',
#        'CDs & Vinyl, World Music, Africa, Soukous',
#        'CDs & Vinyl, World Music, South & Central America, Venezuela',
#        'CDs & Vinyl, World Music, Africa, Cape Verde',
#        'CDs & Vinyl, Classical, Ballets & Dances, Baroque Dance Suites, Courantes',
#        'CDs & Vinyl, Pop, Euro Pop',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Songs & Lieder, Lieder',
#        'CDs & Vinyl, Country, Neotraditional',
#        'CDs & Vinyl, Blues, Modern Blues',
#        'CDs & Vinyl, Latin Music, Ranchera',
#        'CDs & Vinyl, Jazz, Jazz Jam Bands',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Cuba, Rhumba',
#        'CDs & Vinyl, World Music, Africa, Mali',
#        'CDs & Vinyl, Dance & Electronic, Rave',
#        'CDs & Vinyl, Classical, Forms & Genres, Scherzo',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Caprices',
#        'CDs & Vinyl, Broadway & Vocalists',
#        "CDs & Vinyl, Latin Music, Latin Children's",
#        'CDs & Vinyl, Latin Music, Grupero', 'CDs & Vinyl, Latin Music',
#        'CDs & Vinyl, Latin Music, Mexican Cumbia',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Afro-Cuban',
#        'CDs & Vinyl, Latin Music, Cumbia',
#        'CDs & Vinyl, Rock, Singer-Songwriters',
#        'CDs & Vinyl, Classic Rock, Supergroups',
#        'CDs & Vinyl, Blues, Regional Blues',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Te Deum',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Choruses',
#        'CDs & Vinyl, Dance & Electronic, IDM',
#        'CDs & Vinyl, Gospel, Instrumental',
#        'CDs & Vinyl, World Music, North America, Eskimo & Inuit',
#        'CDs & Vinyl, World Music, Middle East, Iraq',
#        'CDs & Vinyl, Folk, British & Celtic Folk',
#        'CDs & Vinyl, Classical, Ballets & Dances',
#        'CDs & Vinyl, Holiday & Wedding, Kwanzaa',
#        'CDs & Vinyl, Alternative Rock, Hardcore & Punk',
#        'CDs & Vinyl, World Music, South & Central America, Brazil, Tropiclia',
#        'CDs & Vinyl, Holiday & Wedding, Hanukkah',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Soca',
#        'CDs & Vinyl, Jazz, Brazilian Jazz',
#        'CDs & Vinyl, Opera & Classical Vocal, Vocal Non-Opera, Virelais',
#        'CDs & Vinyl, Pop, Euro Pop, Italian Pop',
#        'CDs & Vinyl, Rap & Hip-Hop, Southern Rap',
#        'CDs & Vinyl, Jazz, Orchestral Jazz',
#        'CDs & Vinyl, Alternative Rock, Ska, British Ska',
#        'CDs & Vinyl, Rap & Hip-Hop, International Rap',
#        'CDs & Vinyl, Gospel, Traditional',
#        'CDs & Vinyl, Dance & Electronic, Dubstep',
#        'CDs & Vinyl, Classical, Chamber Music, Septets',
#        'CDs & Vinyl, Country, Instrumental',
#        'CDs & Vinyl, Alternative Rock, Indie & Lo-Fi, Electronic Pop',
#        'CDs & Vinyl, World Music, Europe, British Isles',
#        'CDs & Vinyl, Latin Music, Samba',
#        'CDs & Vinyl, Christian, Accompaniment',
#        'CDs & Vinyl, Alternative Rock, Krautrock',
#        'CDs & Vinyl, Jazz, European Jazz',
#        'CDs & Vinyl, World Music, Middle East, Lebanon',
#        'CDs & Vinyl, Classical, Chamber Music, Sextets',
#        'CDs & Vinyl, World Music, South & Central America, Costa Rica',
#        'CDs & Vinyl, Alternative Rock, Indie & Lo-Fi, Twee Pop',
#        'CDs & Vinyl, Latin Music, Vallenato',
#        'CDs & Vinyl, Latin Music, Latin Electronica',
#        'CDs & Vinyl, Latin Music, Reggaeton',
#        'CDs & Vinyl, Classic Rock, Psychedelic Rock, Straight, Inseam: 34", 98% Cotton, 2% Elastane, Machine wash cold with like colors. Tumble dry low. Remove promptly. Warm iron if needed. Non-chlorine bleach only.',
#        'CDs & Vinyl, Latin Music, Latin Christian',
#        'CDs & Vinyl, World Music, South & Central America, Ecuador',
#        'CDs & Vinyl, Latin Music, Duranguense',
#        'CDs & Vinyl, Alternative Rock, Math Rock',
#        'CDs & Vinyl, Latin Music, Latin Pop, Made in USA, Classic round collar, Fashional design, Comfortable cuffs, Soft material, 100% Cotton, 100% Custom',
#        'CDs & Vinyl, World Music, Pacific Islands',
#        'CDs & Vinyl, Latin Music, Tierra Caliente',
#        'CDs & Vinyl, Pop, Korean Pop', 'CDs & Vinyl, Rock, Progressive',
#        'CDs & Vinyl, World Music, Caribbean & Cuba, Bahamas, Straight, Inseam: 34, 73% Cotton, 18% Polyester, 7% Rayon, 2% Elastane, Machine wash cold with like colors. Tumble dry low. Remove promptly. Warm iron if needed. Non-chlorine bleach only.'],
#       dtype=object)

# %%
physicals[physicals["category"] == 'CDs & Vinyl, Classic Rock, Psychedelic Rock, Straight, Inseam: 34", 98% Cotton, 2% Elastane, Machine wash cold with like colors. Tumble dry low. Remove promptly. Warm iron if needed. Non-chlorine bleach only.']
# Out:
#                                                  category  \
# 180485  CDs & Vinyl, Classic Rock, Psychedelic Rock, S...
#
#                                               description  \
# 180485  Straight cut jean with hand-sanding, whiskerin...
#
#                                            title    also_buy         brand  \
# 180485  Rock Revival - Mens Foust Straight Jeans  B074VD3BQF  Rock Revival
#
#                                                   feature rank  \
# 180485  Straight, Inseam: 34", 98% Cotton, 2% Elastane...   []
#
#                                                 also_view price        asin
# 180485  B074VD3BQF, B003307NWC, B00029LOC2, B005OSFR60...        B0000ZMH2Y

# %%
physicals = physicals.drop(508788)
physicals = physicals.drop(322311)
physicals = physicals.drop(180485)
physicals = physicals.drop(71129)

# %%
physicals = physicals[physicals["feature"] != 'Make your Unique, Exclusive & Fashionable Phone Case, Provides protection against daily wear and tear, scratches, marks and scrapes. with precision cutouts for buttons, ports and camera., Provides maximum scratch resistance from objects in your purse or pocket., Flexible, Elastic, and Durable material allows a soft, comfortable grip., It is a good idea to keep it as a collection or to send it as a gift to your friends']

# %%
physicals = physicals[physicals["title"] != ""]

# %%
len(physicals["title"].unique())
# Out:
# 338872

# %%
physicals = physicals[~physicals["title"].str.startswith("<")]

# %%
len(physicals)
# Out:
# 399836

# %%
physicals.to_csv ('physicals.csv', index = False, header=True)

# %% [markdown]
# # Digital Music

# %% [markdown]
# Summary:
# - Removed tech1, tech2, imgurl, fit, imgurlhighres, similar_item, date, and details due to not enough data
# - Removed main_cat due to unhelpful distribution and mostly misleading info
# - Cleaning the price values since there are CSS in some records
# - Clean the main category section since they have HTML containing the real category string
# - Convert lists to strings for making cleaner dataframes
# - Use main category to find unrelated items and remove them
# - Remove duplicates

# %%
### load the meta data
dig_path = path + 'meta_Digital_Music.json.gz'
dig_data = []
with gzip.open(dig_path) as f:
    for l in f:
        dig_data.append(json.loads(l.strip()))
    
# total length of list, this number equals total number of products
print(len(dig_data))
# Out:
# 74347

# %% [markdown]
# There are 74,347 digital music products in dataset. Much less the 516,914 physical ones in the set.

# %%
# convert list into pandas dataframe

dig_df = pd.DataFrame.from_dict(dig_data)

print(len(dig_df))
# Out:
# 74347

# %%
digtemp = dig_df.fillna('')
digitals = digtemp[~digtemp.title.str.contains('getTime')] # filter those unformatted rows
print(len(digitals))
# Out:
# 74347

# %%
digitals.head()
# Out:
#   category tech1                                        description fit  \
# 0       []                                                       []
# 1       []                                                       []
# 2       []                                                       []
# 3       []                                                       []
# 4       []        [1. Losing Game 2. I Can't Wait 3. Didn't He S...
#
#                                title  \
# 0       Master Collection Volume One
# 1  Hymns Collection: Hymns 1 &amp; 2
# 2        Early Works - Don Francisco
# 3      So You Wanna Go Back to Egypt
# 4          Early Works - Dallas Holm
#
#                                             also_buy tech2  \
# 0  [B000002UEN, B000008LD5, B01J804JKE, 747403435...
# 1                           [5558154950, B00014K5V4]
# 2  [B00004RC05, B003H8F4NA, B003ZFVHPO, B003JMP1Z...
# 3  [B0000275QQ, 0001393774, 0001388312, B0016CP2G...
# 4  [B0002N4JP2, 0760131694, B00002EQ79, B00150K8J...
#
#                     brand feature                      rank  \
# 0     John Michael Talbot      []   58,291 in CDs & Vinyl (
# 1  Second Chapter of Acts      []   93,164 in CDs & Vinyl (
# 2           Don Francisco      []  875,825 in CDs & Vinyl (
# 3             Keith Green      []  203,263 in CDs & Vinyl (
# 4             Dallas Holm      []  399,269 in CDs & Vinyl (
#
#                                            also_view  \
# 0  [B000002UEN, B000008LD5, 7474034352, B000008LD...
# 1  [B000008KJ3, B000008KJ0, 5558154950, B000UN8KZ...
# 2  [B003H8F4NA, B003ZFVHPO, B003JMP1ZK, B00004RC0...
# 3  [B00000I7JO, B0016CP2GS, 0001393774, B0000275Q...
# 4  [B0002N4JP2, 0760131694, B00150K8JC, B003MTXNV...
#
#                                             main_cat similar_item date  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#     price        asin imageURL imageURLHighRes details
# 0  $18.99  0001377647       []              []
# 1          0001529145       []              []
# 2          0001527134       []              []
# 3  $13.01  0001388703       []              []
# 4          0001526146       []              []

# %%
digitals = digitals.drop("imageURL", 1)
digitals = digitals.drop("imageURLHighRes", 1)

# %%
digitals[digitals["tech1"] != ""].count()
# Out:
# category        0
# tech1           0
# description     0
# fit             0
# title           0
# also_buy        0
# tech2           0
# brand           0
# feature         0
# rank            0
# also_view       0
# main_cat        0
# similar_item    0
# date            0
# price           0
# asin            0
# details         0
# dtype: int64

# %%
digitals[digitals["tech2"] != ""].count()
# Out:
# category        0
# tech1           0
# description     0
# fit             0
# title           0
# also_buy        0
# tech2           0
# brand           0
# feature         0
# rank            0
# also_view       0
# main_cat        0
# similar_item    0
# date            0
# price           0
# asin            0
# details         0
# dtype: int64

# %%
digitals[digitals["fit"] != ""].count()
# Out:
# category        0
# tech1           0
# description     0
# fit             0
# title           0
# also_buy        0
# tech2           0
# brand           0
# feature         0
# rank            0
# also_view       0
# main_cat        0
# similar_item    0
# date            0
# price           0
# asin            0
# details         0
# dtype: int64

# %%
digitals[digitals["similar_item"] != ""].count()
# Out:
# category        0
# tech1           0
# description     0
# fit             0
# title           0
# also_buy        0
# tech2           0
# brand           0
# feature         0
# rank            0
# also_view       0
# main_cat        0
# similar_item    0
# date            0
# price           0
# asin            0
# details         0
# dtype: int64

# %%
digitals[digitals["date"] != ""].count()
# Out:
# category        5
# tech1           5
# description     5
# fit             5
# title           5
# also_buy        5
# tech2           5
# brand           5
# feature         5
# rank            5
# also_view       5
# main_cat        5
# similar_item    5
# date            5
# price           5
# asin            5
# details         5
# dtype: int64

# %%
digitals[digitals["details"] != ""].count()
# Out:
# category        73813
# tech1           73813
# description     73813
# fit             73813
# title           73813
# also_buy        73813
# tech2           73813
# brand           73813
# feature         73813
# rank            73813
# also_view       73813
# main_cat        73813
# similar_item    73813
# date            73813
# price           73813
# asin            73813
# details         73813
# dtype: int64

# %%
digitals[digitals["details"] != ""].head()
# Out:
#     category tech1                                        description fit  \
# 534       []        [Cassette tape and book in as new condition, a...
# 535       []        [Gentle Persuasions ~ Electrifying Thunderstorms]
# 536       []                                                       []
# 537       []                                                       []
# 538       []                     [NEW Combo BLUWAVS CD and FLAC FILE]
#
#                                          title  \
# 534  Wee Sing Children's Songs and Fingerplays
# 535                 Electrifying Thunderstorms
# 536         Wilderness Journey... Earth Sounds
# 537                        OSCARS TRASHY SONGS
# 538                      Don't Drink His Blood
#
#                                  also_buy tech2  \
# 534                                    []
# 535  [B003DQOT9Q, B000ACJHI4, B000ARD7EO]
# 536                                    []
# 537  [B000002BR5, B000002BJZ, B01MU9RP2X]
# 538                                    []
#
#                                      brand feature  \
# 534                               Wee Sing      []
# 535  Gentle Persuasion The Sound of Nature      []
# 536                         Gordon Hempton      []
# 537                          Sesame Street      []
# 538                           Howard Hello      []
#
#                              rank  \
# 534  484,072 in CDs &amp; Vinyl (
# 535       79,509 in CDs & Vinyl (
# 536    2,736,764 in CDs & Vinyl (
# 537    3,298,999 in CDs & Vinyl (
# 538                            []
#
#                                              also_view  \
# 534  [0843113626, B000NVL9ME, B0000003IO, B01K8O26Y...
# 535                                                 []
# 536                                                 []
# 537  [B000040JG6, B00CMA7WCK, B000002BR5, B07JHJTQ2...
# 538                                                 []
#
#                                               main_cat similar_item date  \
# 534  <img src="https://images-na.ssl-images-amazon....
# 535  <img src="https://images-na.ssl-images-amazon....
# 536  <img src="https://images-na.ssl-images-amazon....
# 537  <img src="https://images-na.ssl-images-amazon....
# 538  <img src="https://images-na.ssl-images-amazon....
#
#       price        asin                                            details
# 534          6303223990                            {'ASIN:': '6303223990'}
# 535  $12.98  6303277373  {'Number of Discs:': '1', 'Label:': 'ESSEX ENT...
# 536   $5.00  6303435238                            {'ASIN:': '6303435238'}
# 537          630438307X  {'Number of Discs:': '1', 'Label:': 'SONY WOND...
# 538          6308051551  {'Label:': 'Temporary Residence Ltd', 'ASIN:':...

# %% [markdown]
# Most records in both digitals and physicals have stuff in the details column but they aren't useful so they can be removed

# %%
digitals[digitals["price"] != ""].count()
# Out:
# category        46450
# tech1           46450
# description     46450
# fit             46450
# title           46450
# also_buy        46450
# tech2           46450
# brand           46450
# feature         46450
# rank            46450
# also_view       46450
# main_cat        46450
# similar_item    46450
# date            46450
# price           46450
# asin            46450
# details         46450
# dtype: int64

# %%
digitals = digitals.drop("tech1", 1)
digitals = digitals.drop("tech2", 1)
digitals = digitals.drop("fit", 1)
digitals = digitals.drop("similar_item", 1)
digitals = digitals.drop("date", 1)
digitals = digitals.drop("details", 1)

# %%
digitals.head()
# Out:
#   category                                        description  \
# 0       []                                                 []
# 1       []                                                 []
# 2       []                                                 []
# 3       []                                                 []
# 4       []  [1. Losing Game 2. I Can't Wait 3. Didn't He S...
#
#                                title  \
# 0       Master Collection Volume One
# 1  Hymns Collection: Hymns 1 &amp; 2
# 2        Early Works - Don Francisco
# 3      So You Wanna Go Back to Egypt
# 4          Early Works - Dallas Holm
#
#                                             also_buy                   brand  \
# 0  [B000002UEN, B000008LD5, B01J804JKE, 747403435...     John Michael Talbot
# 1                           [5558154950, B00014K5V4]  Second Chapter of Acts
# 2  [B00004RC05, B003H8F4NA, B003ZFVHPO, B003JMP1Z...           Don Francisco
# 3  [B0000275QQ, 0001393774, 0001388312, B0016CP2G...             Keith Green
# 4  [B0002N4JP2, 0760131694, B00002EQ79, B00150K8J...             Dallas Holm
#
#   feature                      rank  \
# 0      []   58,291 in CDs & Vinyl (
# 1      []   93,164 in CDs & Vinyl (
# 2      []  875,825 in CDs & Vinyl (
# 3      []  203,263 in CDs & Vinyl (
# 4      []  399,269 in CDs & Vinyl (
#
#                                            also_view  \
# 0  [B000002UEN, B000008LD5, 7474034352, B000008LD...
# 1  [B000008KJ3, B000008KJ0, 5558154950, B000UN8KZ...
# 2  [B003H8F4NA, B003ZFVHPO, B003JMP1ZK, B00004RC0...
# 3  [B00000I7JO, B0016CP2GS, 0001393774, B0000275Q...
# 4  [B0002N4JP2, 0760131694, B00150K8JC, B003MTXNV...
#
#                                             main_cat   price        asin
# 0  <img src="https://images-na.ssl-images-amazon....  $18.99  0001377647
# 1  <img src="https://images-na.ssl-images-amazon....          0001529145
# 2  <img src="https://images-na.ssl-images-amazon....          0001527134
# 3  <img src="https://images-na.ssl-images-amazon....  $13.01  0001388703
# 4  <img src="https://images-na.ssl-images-amazon....          0001526146

# %%
digitals["category"] = digitals["category"].apply(', '.join)
digitals["description"] = digitals["description"].apply(', '.join)
digitals["also_buy"] = digitals["also_buy"].apply(', '.join)
digitals["feature"] = digitals["feature"].apply(', '.join)
digitals["also_view"] = digitals["also_view"].apply(', '.join)

# %%
digitals["category"].unique()
# Out:
# array(['', 'Digital Music, Blues, Electric Blues Guitar',
#        'Digital Music, Jazz', 'Digital Music, Folk',
#        'Digital Music, Blues', 'Digital Music, Alternative Rock',
#        'Digital Music, Broadway & Vocalists',
#        'Digital Music, Miscellaneous, Poetry, Spoken Word & Interviews'],
#       dtype=object)

# %% [markdown]
# Wayyy less categories than on physical....

# %%
digitals[digitals["category"] != ''].count()
# Out:
# category       7
# description    7
# title          7
# also_buy       7
# brand          7
# feature        7
# rank           7
# also_view      7
# main_cat       7
# price          7
# asin           7
# dtype: int64

# %% [markdown]
# Category is not useful for this dataset.

# %%
digitals[digitals["brand"] != ''].count()
# Out:
# category       59876
# description    59876
# title          59876
# also_buy       59876
# brand          59876
# feature        59876
# rank           59876
# also_view      59876
# main_cat       59876
# price          59876
# asin           59876
# dtype: int64

# %%
digitals[digitals["main_cat"] != ''].count()
# Out:
# category       74347
# description    74347
# title          74347
# also_buy       74347
# brand          74347
# feature        74347
# rank           74347
# also_view      74347
# main_cat       74347
# price          74347
# asin           74347
# dtype: int64

# %%
digitals["main_cat"].unique()
# Out:
# array(['<img src="https://images-na.ssl-images-amazon.com/images/G/01/digital/music/logos/amzn_music_logo_subnav._CB471835632_.png" class="nav-categ-image" alt="Digital Music"/>',
#        '<img src="https://images-na.ssl-images-amazon.com/images/G/01/digital/music/logos/amzn_music_logo_subnav._CB471835632_.png" class="nav-categ-image" alt="Digital Music" />',
#        '<img src="https://m.media-amazon.com/images/G/01/digital/music/logos/amzn_music_logo_subnav._CB471835632_.png" class="nav-categ-image" alt="Digital Music"/>',
#        '<img src="https://m.media-amazon.com/images/G/01/digital/music/logos/amzn_music_logo_subnav._CB471835632_.png" class="nav-categ-image" alt="Digital Music" />',
#        'All Electronics'], dtype=object)

# %% [markdown]
# We can remove main_cat given that it doesn't give us anything insightful. It's all the same "Digital Music" category.

# %%
digitals = digitals.drop("main_cat", 1)

# %%
digitals.head()
# Out:
#   category                                        description  \
# 0
# 1
# 2
# 3
# 4           1. Losing Game 2. I Can't Wait 3. Didn't He Sh...
#
#                                title  \
# 0       Master Collection Volume One
# 1  Hymns Collection: Hymns 1 &amp; 2
# 2        Early Works - Don Francisco
# 3      So You Wanna Go Back to Egypt
# 4          Early Works - Dallas Holm
#
#                                             also_buy                   brand  \
# 0  B000002UEN, B000008LD5, B01J804JKE, 7474034352...     John Michael Talbot
# 1                             5558154950, B00014K5V4  Second Chapter of Acts
# 2  B00004RC05, B003H8F4NA, B003ZFVHPO, B003JMP1ZK...           Don Francisco
# 3  B0000275QQ, 0001393774, 0001388312, B0016CP2GS...             Keith Green
# 4  B0002N4JP2, 0760131694, B00002EQ79, B00150K8JC...             Dallas Holm
#
#   feature                      rank  \
# 0           58,291 in CDs & Vinyl (
# 1           93,164 in CDs & Vinyl (
# 2          875,825 in CDs & Vinyl (
# 3          203,263 in CDs & Vinyl (
# 4          399,269 in CDs & Vinyl (
#
#                                            also_view   price        asin
# 0  B000002UEN, B000008LD5, 7474034352, B000008LDH...  $18.99  0001377647
# 1  B000008KJ3, B000008KJ0, 5558154950, B000UN8KZE...          0001529145
# 2  B003H8F4NA, B003ZFVHPO, B003JMP1ZK, B00004RC05...          0001527134
# 3  B00000I7JO, B0016CP2GS, 0001393774, B0000275QQ...  $13.01  0001388703
# 4  B0002N4JP2, 0760131694, B00150K8JC, B003MTXNVE...          0001526146

# %%
digitals["price"].unique()
# Out:
# array(['$18.99', '', '$13.01', ..., '$102.19', '$109.60', '$92.06'],
#       dtype=object)

# %%
digitals[~digitals["price"].str.startswith("$")]["price"].unique()
# Out:
# array(['',
#        '.a-section.a-spacing-mini{margin-bottom:6px!important;margin-top:10px}#actionPanel #availability{font-size:17px!important;font-weight:400!important}#actionPanel #availability p#pa_other_website_text{color:#888!important;margin-top:6px}#actionPanel #merchant-info{font-size:13px;color:#333}#actionPanel #pa_avaliability_message{font-size:12px!important;font-weight:400!important}#actionPanel #pa_avaliability_message a{white-space:normal!important}#actionPanel #pa_avaliability_message span{color:#888!important}#actionPanel #availability-brief #availability+br{display:none}// This is an empty file #actionPanel #bbop-sbbop-container{margin-bottom:0}#actionPanel .buybox-main{padding:0 40px}#actionPanel #priceblock_ourprice_row span.feature img{padding-top:8px!important}#actionPanel #onetimeOption .a-radio-label #priceBadging_feature_div a:not(.a-popover-trigger),#actionPanel #usedOption .a-radio-label #priceBadging_feature_div a:not(.a-popover-trigger){display:none}#actionPanel #pa_feedbackForm_rootmain{text-align:center}.burj #buybox_feature_div #deal #regularBuybox{margin-bottom:14px!important}.burj #hero-quick-promo hr{display:none}#actionPanel #hqp{margin-top:26px}#actionPanel #hqp #amsDetailRight{margin-bottom:18px}#actionPanel #hqp #amsDetailRightWide{margin-bottom:18px}#actionPanel #hqp #hqp-left{margin-bottom:18px}div#hqp-bottom.a-section.burj{margin-bottom:0}.burj #instantOrderUpdate_feature_div',
#        '\n\n\n<script',
#        '.a-box-inner{background-color:#fff}#alohaBuyBoxWidget .selected{background-color:#fffbf3;border-color:#e77600;box-shadow:0 0 3px rgba(228,121,17,.5)}#alohaBuyBoxWidget .contract-not-available{color:gray}#aloha-cart-popover .aloha-cart{height:auto;overflow:hidden}#aloha-cart-popover #aloha-cartInfo{float:left}#aloha-cart-popover #aloha-cart-details{float:right;margin-top:1em}#aloha-cart-popover .deviceContainer{width:160px;float:left;padding-right:10px;border-right:1px solid #ddd}#aloha-cart-popover li:last-child{border-right:0}#aloha-cart-popover .aloha-device-title{height:3em;overflow:hidden}#aloha-cart-popover .aloha-thumbnail-container{height:100px;margin-bottom:1em;text-align:center}#aloha-cart-popover .aloha-price-container{text-align:center}#aloha-cart-popover .aloha-thumbnail-container img{height:inherit}#aloha-cart-popover .aloha-cart{border-top:1px solid #ddd;border-bottom:1px solid #ddd}#aloha-cart-popover #aloha-cart-info{margin-right:0}#alohaBuyBoxWidget .without-contract-subheading{margin-right:0}#aloha-bb-help-nodes .aloha-bb-contract-term-heading{color:gray;font-family:arial;margin-top:.5em;text-align:center;height:.7em;border-bottom:1px solid gray;margin-bottom:1.6em}#aloha-bb-help-nodes .aloha-bb-contract-term-heading span{background-color:#fff;padding:0 10px 0 10px}#alohaAvailabilityUS_feature_div .availability a{text-decoration:none}#alohaPricingWidget a{text-decoration:none}#alohaAvailabilityUS_feature_div .availability{margin-top:-4px;margin-bottom:0}#alohaBuyBoxWidget .select-transaction-alert .a-icon-alert{top:18px;left:3px}#alohaBuyBoxWidget .select-transaction-alert .a-alert-container{padding-left:39px;width:290px}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .contract-container .contract-term-heading a{text-decoration:none}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .annual-contract-box .a-icon-popover{display:none}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .contract-container .annual-contract-box{cursor:pointer;cursor:hand}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .aloha-buybox-price{font-size:15px}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget #linkOffSection a{text-decoration:none}#alohaBuyBoxUS_feature_div .lockedUsedBuyboxContainer{padding-left:3.5%}#alohaBuyBoxUS_feature_div .alohaBuyboxUtilsNoWrap{white-space:nowrap}.hidden{display:none}.simo-no-padding{padding:0}.carrier-reviews-cell{padding-left:10px}.carrier-reviews-bordered-cell{border:1px dotted #ccc}.carrier-reviews-selected-cell{background-color:#ffd}#aloha-carrier-compatibility-modal-table-description{margin-top:10px;margin-bottom:14px}.aloha-carrier-compatibility-sortable-header.carrier{min-width:97px}.aloha-carrier-compatibility-sortable-header.compatibility{min-width:156px}.aloha-carrier-compatibility-sortable-header div{float:left}.aloha-carrier-compatibility-sortable-header i.a-icon{margin-left:10px;margin-top:4px}#aloha-carrier-compatibility-overview-table.a-bordered.a-vertical-stripes td:nth-child(2n),#aloha-carrier-compatibility-overview-table.a-bordered.a-vertical-stripes th:nth-child(2n){background-color:initial}#aloha-carrier-compatibility-modal-table.a-bordered.a-vertical-stripes td:nth-child(2n),#aloha-carrier-compatibility-modal-table.a-bordered.a-vertical-stripes th:nth-child(2n){background-color:initial}#aloha-carrier-compatibility-table.a-bordered.a-vertical-stripes th:nth-child(2n),.aloha-carrier-compatibility-table.a-bordered.a-vertical-stripes td:nth-child(2n){background-color:transparent}.aloha-carrier-compatibility-column-gray{background-color:#f6f6f6}.aloha-carrier-compatibility-modal-table-row .aloha-carrier-compatibility-tech-text,.aloha-carrier-compatibility-modal-table-row .carrier-name,.aloha-carrier-compatibility-modal-table-row .carrier-rating-summary{min-height:27px;display:inline-block;cursor:default}.aloha-carrier-compatibility-modal-table-row .aloha-carrier-compatibility-tech-text:first-line,.aloha-carrier-compatibility-modal-table-row .carrier-name:first-line,.aloha-carrier-compatibilit ...
#       dtype=object)

# %%
digitals["price"] = digitals.apply(lambda x: "" if not x["price"].startswith("$") else x["price"], axis=1)

# %%
digitals[digitals["feature"] != ""].count()
# Out:
# category       89
# description    89
# title          89
# also_buy       89
# brand          89
# feature        89
# rank           89
# also_view      89
# price          89
# asin           89
# dtype: int64

# %%
digitals = digitals.drop(29840)

# %%
len(digitals)
# Out:
# 74346

# %%
digitals = digitals.astype(str)

# %%
digitals = digitals.drop_duplicates()

# %%
digitals = digitals[digitals["title"] != ""]

# %%
len(digitals["title"].unique())
# Out:
# 59574

# %%
digitals = digitals[~digitals["title"].str.startswith("<")]

# %%
len(digitals)
# Out:
# 61197

# %%
digitals.to_csv('digitals.csv', index = False, header=True)

# %% [markdown]
# Also drops quite a bit of duplicates
