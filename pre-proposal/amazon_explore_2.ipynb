# %% [markdown]
# # Exploring the Music Datasets

# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/auraulloa/Desktop/DataSciencePipeline

# %%
path = '/Users/auraulloa/Desktop/DataSciencePipeline/'
dig_music_path = path + 'amazon_dataset/amazon_reviews_us_Digital_Music.tsv'
music_path = path + 'amazon_dataset/amazon_reviews_us_Music.tsv'

# %%
music_df = pd.read_csv(music_path, delimiter = '\t', quoting = 3)

# %%
digital_music_df = pd.read_csv(dig_music_path, delimiter = '\t', quoting = 3)

# %%
music_df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     10140119  R3LI5TRP3YIDQL  B00TXH4OLC       384427924
# 1          US     27664622  R3LGC3EKEG84PX  B00B6QXN6U       831769051
# 2          US     45946560   R9PYL3OYH55QY  B001GCZXW6        14067376
# 3          US     15146326  R3PWBAWUS4NT0Q  B000003EK6       566295619
# 4          US     16794688  R15LYP3O51UU9E  B00N1F0BKK       210426072
#
#                    product_title product_category  star_rating  helpful_votes  \
# 0  Whatever's for Us: Remastered            Music            5              0
# 1    Same Trailer Different Park            Music            5              0
# 2            Soaring (Jazz Club)            Music            5              0
# 3                CARIBBEAN PARTY            Music            3              0
# 4                    Pain Killer            Music            5              0
#
#    total_votes vine verified_purchase          review_headline  \
# ...

# %%
digital_music_df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     10293599  R14LVB34Z2Z53I  B000YMOQZY       262935067
# 1          US      6087195  R2M0R9CWPC82LT  B00ISAEC80       452318038
# 2          US     33717063   RQNQI2R3BM52A  B00VBB6AVU       675969129
# 3          US     14948020   RTUIX1135HUAB  B008A5POJO       282925893
# 4          US     21694522   RE3QSAT8TL010  B014CW2RN4       109077793
#
#                 product_title        product_category  star_rating  \
# 0   Knockin' On Heaven's Door  Digital_Music_Purchase            5
# 1                    Flawless  Digital_Music_Purchase            5
# 2            Scandal of Grace  Digital_Music_Purchase            4
# 3          I Surrender (Live)  Digital_Music_Purchase            5
# 4  We Are Young (Jersey Club)  Digital_Music_Purchase            4
#
#    helpful_votes  total_votes vine verified_purchase  \
# 0              0            0    N                 Y
# ...

# %%
# seems like music downloads are done per song rather than album, this might screw with comparisons

# %%
len(music_df)
# Out:
# 4751577

# %%
len(digital_music_df)
# Out:
# 1688884

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4751577 entries, 0 to 4751576
# Data columns (total 15 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   marketplace        object
#  1   customer_id        int64
#  2   review_id          object
#  3   product_id         object
#  4   product_parent     int64
#  5   product_title      object
#  6   product_category   object
#  7   star_rating        int64
#  8   helpful_votes      int64
#  9   total_votes        int64
#  10  vine               object
#  11  verified_purchase  object
#  12  review_headline    object
#  13  review_body        object
#  14  review_date        object
# dtypes: int64(5), object(10)
# memory usage: 543.8+ MB

# %%
# somehow even cleaner than videos since some of the numerical vals are already converted 
# from generic objects

# %%
digital_music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1688884 entries, 0 to 1688883
# Data columns (total 15 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   marketplace        1688884 non-null  object
#  1   customer_id        1688884 non-null  int64
#  2   review_id          1688884 non-null  object
#  3   product_id         1688884 non-null  object
#  4   product_parent     1688884 non-null  int64
#  5   product_title      1688884 non-null  object
#  6   product_category   1688884 non-null  object
#  7   star_rating        1688884 non-null  int64
#  8   helpful_votes      1688884 non-null  int64
#  9   total_votes        1688884 non-null  int64
#  10  vine               1688884 non-null  object
#  11  verified_purchase  1688884 non-null  object
#  12  review_headline    1688833 non-null  object
#  13  review_body        1688823 non-null  object
#  14  review_date        1688884 non-null  object
# ...

# %%
music_df.describe()
# Out:
#         customer_id  product_parent   star_rating  helpful_votes   total_votes
# count  4.751577e+06    4.751577e+06  4.751577e+06   4.751577e+06  4.751577e+06
# mean   3.424994e+07    5.006262e+08  4.436624e+00   2.661673e+00  3.798425e+00
# std    1.498002e+07    2.882080e+08  1.035925e+00   7.791572e+00  9.421686e+00
# min    1.009900e+04    7.340000e+02  1.000000e+00   0.000000e+00  0.000000e+00
# 25%    2.047946e+07    2.510092e+08  4.000000e+00   0.000000e+00  0.000000e+00
# 50%    3.669898e+07    5.003334e+08  5.000000e+00   1.000000e+00  1.000000e+00
# 75%    4.925116e+07    7.512355e+08  5.000000e+00   3.000000e+00  4.000000e+00
# max    5.309659e+07    9.999998e+08  5.000000e+00   2.181000e+03  2.246000e+03

# %%
digital_music_df.describe()
# Out:
#         customer_id  product_parent   star_rating  helpful_votes   total_votes
# count  1.688884e+06    1.688884e+06  1.688884e+06   1.688884e+06  1.688884e+06
# mean   2.864549e+07    4.989743e+08  4.642891e+00   5.002878e-01  7.248224e-01
# std    1.492145e+07    2.882660e+08  8.604528e-01   2.958235e+00  3.792770e+00
# min    1.012800e+04    2.457000e+03  1.000000e+00   0.000000e+00  0.000000e+00
# 25%    1.515693e+07    2.491138e+08  5.000000e+00   0.000000e+00  0.000000e+00
# 50%    2.775266e+07    4.992678e+08  5.000000e+00   0.000000e+00  0.000000e+00
# 75%    4.255546e+07    7.485598e+08  5.000000e+00   0.000000e+00  0.000000e+00
# max    5.309657e+07    9.999997e+08  5.000000e+00   6.090000e+02  7.360000e+02

# %%
digital_music_df['product_category'].unique()
# Out:
# array(['Digital_Music_Purchase'], dtype=object)

# %%
music_df['product_category'].unique()
# Out:
# array(['Music'], dtype=object)

# %%
digital_music_df.isna().sum()
# Out:
# marketplace           0
# customer_id           0
# review_id             0
# product_id            0
# product_parent        0
# product_title         0
# product_category      0
# star_rating           0
# helpful_votes         0
# total_votes           0
# vine                  0
# verified_purchase     0
# review_headline      51
# review_body          61
# review_date           0
# dtype: int64

# %%
music_df.isna().sum()
# Out:
# marketplace            0
# customer_id            0
# review_id              0
# product_id             0
# product_parent         0
# product_title          1
# product_category       0
# star_rating            0
# helpful_votes          0
# total_votes            0
# vine                   0
# verified_purchase      0
# review_headline      165
# review_body           33
# review_date            0
# dtype: int64

# %%
#similarly negligible missing data like our video data

# %%
digital_music_df.isnull().sum()
# Out:
# marketplace           0
# customer_id           0
# review_id             0
# product_id            0
# product_parent        0
# product_title         0
# product_category      0
# star_rating           0
# helpful_votes         0
# total_votes           0
# vine                  0
# verified_purchase     0
# review_headline      51
# review_body          61
# review_date           0
# dtype: int64

# %%
music_df.isnull().sum()
# Out:
# marketplace            0
# customer_id            0
# review_id              0
# product_id             0
# product_parent         0
# product_title          1
# product_category       0
# star_rating            0
# helpful_votes          0
# total_votes            0
# vine                   0
# verified_purchase      0
# review_headline      165
# review_body           33
# review_date            0
# dtype: int64

# %%
music_df.eq('').sum()
# Out:
# marketplace          0
# customer_id          0
# review_id            0
# product_id           0
# product_parent       0
# product_title        0
# product_category     0
# star_rating          0
# helpful_votes        0
# total_votes          0
# vine                 0
# verified_purchase    0
# review_headline      0
# review_body          0
# review_date          0
# dtype: int64

# %%
digital_music_df.eq('').sum()
# Out:
# marketplace          0
# customer_id          0
# review_id            0
# product_id           0
# product_parent       0
# product_title        0
# product_category     0
# star_rating          0
# helpful_votes        0
# total_votes          0
# vine                 0
# verified_purchase    0
# review_headline      0
# review_body          0
# review_date          0
# dtype: int64

# %%
# i also highly doubt these products can be grouped given that digital sells per song while
# physical does per album

# %%
music_df["year"] = music_df["review_date"].map(lambda x: str(x)[:4])

# %%
music_counts = music_df.groupby("year").count()

# %%
music_counts
# Out:
#       marketplace  customer_id  review_id  product_id  product_parent  \
# year
# 1995            1            1          1           1               1
# 1996            4            4          4           4               4
# 1997          106          106        106         106             106
# 1998        35383        35383      35383       35383           35383
# 1999       120626       120626     120626      120626          120626
# 2000       268113       268113     268113      268113          268113
# 2001       227283       227283     227283      227283          227283
# 2002       227880       227880     227880      227880          227880
# 2003       275278       275278     275278      275278          275278
# 2004       271643       271643     271643      271643          271643
# 2005       281125       281125     281125      281125          281125
# 2006       217986       217986     217986      217986          217986
# ...

# %%
digital_music_df["year"] = digital_music_df["review_date"].map(lambda x: str(x)[:4])

# %%
dig_music_counts = digital_music_df.groupby("year").count()

# %%
dig_music_counts
# Out:
#       marketplace  customer_id  review_id  product_id  product_parent  \
# year
# 2000            3            3          3           3               3
# 2001            2            2          2           2               2
# 2002            3            3          3           3               3
# 2003            5            5          5           5               5
# 2004            6            6          6           6               6
# 2005            7            7          7           7               7
# 2006           21           21         21          21              21
# 2007         2312         2312       2312        2312            2312
# 2008        23081        23081      23081       23081           23081
# 2009        36702        36702      36702       36702           36702
# 2010        41258        41258      41258       41258           41258
# 2011        59206        59206      59206       59206           59206
# ...

# %%
# this will work

# %% [markdown]
# # Todo
# ### 1. make graphics of attribute distributions
# ### 2. pare out years
